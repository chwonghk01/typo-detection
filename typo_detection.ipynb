# %%
# !pip install --upgrade pyarrow
# !git clone https://github.com/facebookresearch/fastText.git
# !cd fastText && pip install .
# Out:
# Collecting pyarrow
#   Downloading https://files.pythonhosted.org/packages/36/94/23135312f97b20d6457294606fb70fad43ef93b7bffe567088ebe3623703/pyarrow-0.11.1-cp36-cp36m-manylinux1_x86_64.whl (11.6MB)
#     100% |████████████████████████████████| 11.6MB 4.0MB/s
# Requirement already satisfied, skipping upgrade: numpy>=1.14 in /usr/local/lib/python3.6/dist-packages (from pyarrow) (1.14.6)
# Requirement already satisfied, skipping upgrade: six>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from pyarrow) (1.11.0)
# Installing collected packages: pyarrow
# Successfully installed pyarrow-0.11.1
# Cloning into 'fastText'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 2784 (delta 3), reused 8 (delta 3), pack-reused 2771
# Receiving objects: 100% (2784/2784), 7.68 MiB | 29.80 MiB/s, done.
# Resolving deltas: 100% (1750/1750), done.
# Processing /content/fastText
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.6/dist-packages (from fasttext==0.8.22) (2.2.4)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from fasttext==0.8.22) (40.6.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fasttext==0.8.22) (1.14.6)
# Building wheels for collected packages: fasttext
# done
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gncevtau/wheels/a1/9f/52/696ce6c5c46325e840c76614ee5051458c0df10306987e7443
# Successfully built fasttext
# Installing collected packages: fasttext
# Successfully installed fasttext-0.8.22

# %%
# !wget https://www.wfonts.com/download/data/2014/06/01/simhei/simhei.zip
# !unzip simhei.zip
# !wget https://s3-us-west-1.amazonaws.com/fasttext-vectors/wiki.zh_classical.zip
# !unzip wiki.zh_classical.zip
# Out:
# --2018-12-18 01:56:49--  https://www.wfonts.com/download/data/2014/06/01/simhei/simhei.zip
# Resolving www.wfonts.com (www.wfonts.com)... 104.225.219.210
# Connecting to www.wfonts.com (www.wfonts.com)|104.225.219.210|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10546298 (10M) [application/octetstream]
# Saving to: ‘simhei.zip’
#
# simhei.zip          100%[===================>]  10.06M  18.1MB/s    in 0.6s
#
# 2018-12-18 01:56:50 (18.1 MB/s) - ‘simhei.zip’ saved [10546298/10546298]
#
# Archive:  simhei.zip
#   inflating: chinese.simhei.ttf
#   inflating: SimHei.ttf
#   inflating: sharefonts.net.txt
# --2018-12-18 01:56:53--  https://s3-us-west-1.amazonaws.com/fasttext-vectors/wiki.zh_classical.zip
# Resolving s3-us-west-1.amazonaws.com (s3-us-west-1.amazonaws.com)... 52.219.24.49
# Connecting to s3-us-west-1.amazonaws.com (s3-us-west-1.amazonaws.com)|52.219.24.49|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2253991999 (2.1G) [application/zip]
# Saving to: ‘wiki.zh_classical.zip’
#
# wiki.zh_classical.z 100%[===================>]   2.10G  62.0MB/s    in 37s
#
# 2018-12-18 01:57:30 (58.6 MB/s) - ‘wiki.zh_classical.zip’ saved [2253991999/2253991999]
#
# Archive:  wiki.zh_classical.zip
#   inflating: wiki.zh_classical.vec
#   inflating: wiki.zh_classical.bin

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import models
from sklearn.model_selection import train_test_split
import numpy as np
import fastText

print(tf.VERSION)
print(tf.keras.__version__)
# Out:
# 1.12.0
# 2.1.6-tf

# %%
df = pd.read_parquet('/gdrive/My Drive/typo-detection/article_contents.snappy.parquet')[['article_id', 'main_content']].set_index('article_id')
df = df[~df.main_content.isnull()]
df.head()
# Out:
#                                                  main_content
# article_id
# 3           英超曼聯今晨主場出擊，只能與剛剛上任為車路士的領隊軒迪克打和0:0，近8場未嘗勝績，備受批評...
# 6           港超勁旅南華宣布羅致前厄瓜多爾國腳菲力斯保耶（Felix Borja），簽約一年半；足主張廣...
# 7           阿仙奴走出日前慘吞修咸頓4球的陰影，今晨主場憑奧斯爾一傳一射，以2：0氣走般尼茅夫，以19戰...
# 9           英超今晨其餘賽事，熱刺憑前鋒孫興愍89分鐘的入球，以２：1作客反勝屈福特，暫時升上聯賽榜第3...
# 10          352場英超上陣，170場不失球，令阿仙奴門將施治打破前英格蘭國腳占士紀錄，成為英超史上不失...

# %%
# Train test split articles
train, test = train_test_split(df, test_size=0.2, shuffle=False)
train.shape, test.shape
# Out:
# ((174664, 1), (43667, 1))

# %%
TRAIN_SIZE = -1
TEST_SIZE = -1

# Run tokenizer on char level for training data, support 100k + tokens, with oov token (from keras)
tokenizer = tf.keras.preprocessing.text.Tokenizer(char_level=True, oov_token='<oov>', split='')
tokenizer.fit_on_texts(train[:TRAIN_SIZE].main_content)
len(tokenizer.index_word), tokenizer.word_index['<oov>']
# Out:
# (12496, 1)

# %%
# Split article to 64 chars each for both training and testing
# Keras Articles -> Chars -> Indices -> Pad to 64 chars

SEQ_LENGTH = 32 #@param {type:"integer"}

# def generate_dataset(df, error_prob):
#   seqs = tokenizer.texts_to_sequences(df.main_content)
#   padded_seqs = tf.keras.preprocessing.sequence.pad_sequences(seqs, maxlen=SEQ_LENGTH, padding='post', truncating='post', value=0.0)
  
#   index_word_count = [(tokenizer.word_index[k], v) for k, v in tokenizer.word_counts.items()]
#   index_word_count.append((0, sum([x[1] for x in index_word_count]) / (error_prob) * (1 - error_prob)))
  
#   choice = np.array([x[0] for x in index_word_count])

#   p = np.array([x[1] for x in index_word_count])
#   p = p / np.sum(p)
  
#   # for each sequence, randomly replace the index
#   random_error = np.random.choice(choice, padded_seqs.shape, p=p)
#   random_error_mask = (random_error > 0).astype(int)
  
#   inp = padded_seqs * (1-random_error_mask) + random_error
#   out = random_error_mask
  
#   return inp, out


# TODO: fully utilize corpus insteads of only first 32 tokens
def dataset_generator(corpus, mask_prob=0.15, mask_error_prob=0.8, batch_size=64, seed=42):
  seqs = tokenizer.texts_to_sequences(corpus)
  
  def chunk(list_of_list, chunk_size): 
    result = []
    for l in list_of_list:
      for i in range(len(l) // chunk_size):
        result.append(l[i*chunk_size:i*chunk_size+chunk_size])

    return result
  
  seqs = chunk(seqs, chunk_size=SEQ_LENGTH)
  padded_seqs = tf.keras.preprocessing.sequence.pad_sequences(seqs, maxlen=SEQ_LENGTH, padding='post', truncating='post', value=0.0)
  
  # Create FIXED mask for each full dataset
  masks = np.random.choice([0., 1.,], padded_seqs.shape, p=np.array([1-mask_prob, mask_prob]))
  
  # Word choice by count frequency
  index_word_count = [(tokenizer.word_index[k], v) for k, v in tokenizer.word_counts.items()]
  choice = np.array([x[0] for x in index_word_count])
  p = np.array([x[1] for x in index_word_count])
  p = p / np.sum(p)

  
  # Uniformly random sample a batch of (padded_seq, mask)
  while True:
    idx = np.random.randint(padded_seqs.shape[0], size=batch_size)
    inp = padded_seqs[idx]
    out = masks[idx]
    
    # replace each masked token by 1-mask_error_prob the original word, mask_error_prob a randomly sampled word
    out = out * np.random.choice([0., 1.,], out.shape, p=np.array([1-mask_error_prob, mask_error_prob]))
    
    random_error = np.random.choice(choice, inp.shape, p=p)
    inp = inp * (1-out) + random_error * out
    
    yield (inp, out)

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import font_manager
import numpy as np
import seaborn as sns

def visualize(inp, truth, pred=None, display_rows=5):
  font_files = font_manager.findSystemFonts(fontpaths='/content')
  font_list = font_manager.createFontList(font_files)
  font_manager.fontManager.ttflist.extend(font_list)
  sns.set_style("darkgrid",{"font.sans-serif":['simhei', 'Arial']})

  fig, ax = plt.subplots(figsize=(24 * SEQ_LENGTH // 64,display_rows / 3))
  sns.heatmap(truth[:display_rows], \
    annot=np.array([[c for c in row[::2]] for row in tokenizer.sequences_to_texts(inp)[:display_rows]]), \
    fmt='', cmap="YlGnBu", ax=ax, vmin=0, vmax=1)
  
  if pred is not None:
    fig, ax = plt.subplots(figsize=(24 * SEQ_LENGTH // 64,display_rows / 3))
    sns.heatmap(pred[:display_rows], \
      annot=np.array([[c for c in row[::2]] for row in tokenizer.sequences_to_texts(inp)[:display_rows]]), \
      fmt='', cmap="YlGnBu", ax=ax, vmin=0, vmax=1)

# %%
# tokenizer.index_word
ft = fastText.load_model('./wiki.zh_classical.bin')

FT_EMB_SIZE = 300

fasttext_emb = np.zeros((len(tokenizer.index_word) + 1, FT_EMB_SIZE))
for idx, word in tokenizer.index_word.items():
  fasttext_emb[idx] = ft.get_word_vector(word)
  
fasttext_emb[:5]
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 1.96946334e-04,  1.22728362e-03, -2.59545923e-04, ...,
#          6.70105277e-04, -2.94898928e-04,  2.82796507e-04],
#        [ 9.10380185e-02, -5.44981882e-02, -3.35275382e-02, ...,
#         -1.62986919e-01, -1.13570802e-01,  9.72174481e-02],
#        [-1.56043924e-03, -3.07246787e-03, -2.24617636e-03, ...,
#         -3.23857740e-03,  8.81240587e-04, -6.76950789e-04],
#        [ 1.48805141e-01,  7.97280390e-03, -5.96142173e-01, ...,
#          1.35237249e-02,  4.78576571e-02,  4.08989703e-03]])

# %%
EMBEDDING_SIZE = 128 #@param {type:"integer"}
GRU_SIZE = EMBEDDING_SIZE // 2
  
def build_model():
#   model = models.Sequential()
  inp = layers.Input((SEQ_LENGTH,), dtype='int32')
  emb = layers.Embedding(len(tokenizer.index_word) + 1, EMBEDDING_SIZE, input_length=SEQ_LENGTH)(inp)
  
  ft_emb = layers.Embedding(len(tokenizer.index_word) + 1, FT_EMB_SIZE, weights=[fasttext_emb], trainable=False, input_length=SEQ_LENGTH)(inp)
  
  emb_input = layers.Concatenate()([emb, ft_emb])
  
  gru = layers.Bidirectional(layers.CuDNNGRU(GRU_SIZE, return_sequences=True))(emb_input)
  gru = layers.Bidirectional(layers.CuDNNGRU(GRU_SIZE, return_sequences=True))(gru)
  
  final = layers.Add()([gru, emb])
#   gru = layers.CuDNNGRU(GRU_SIZE, return_sequences=True)(gru)
  
  pred = layers.Dense(1, activation='sigmoid')(final)
  out = layers.Flatten()(pred)
  
  model = models.Model(inputs=inp, outputs=out)
  model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['mae', 'acc'])
  return model
  
model = build_model()
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 32)           0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 32, 128)      1599616     input_2[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 32, 300)      3749100     input_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 428)      0           embedding_2[0][0]
#                                                                  embedding_3[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 32, 128)      189696      concatenate_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 32, 128)      74496       bidirectional_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 128)      0           bidirectional_3[0][0]
#                                                                  embedding_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 32, 1)        129         add_1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 32)           0           dense_1[0][0]
# ==================================================================================================
# Total params: 5,613,037
# Trainable params: 1,863,937
# Non-trainable params: 3,749,100
# __________________________________________________________________________________________________

# %%
from sklearn.metrics import roc_auc_score, precision_score, recall_score
from tensorflow.keras.callbacks import Callback

class metrics(Callback):
    def __init__(self, validation_data):
#         self.x = training_data[0]
#         self.y = training_data[1]
        self.x_val = validation_data[0]
        self.y_val = validation_data[1]


    def on_train_begin(self, logs={}):
        return

    def on_train_end(self, logs={}):
        return

    def on_epoch_begin(self, epoch, logs={}):
        return

    def on_epoch_end(self, epoch, logs={}):
#         y_pred = self.model.predict(self.x)
#         roc = roc_auc_score(self.y, y_pred)
#         prec = precision_score(np.ndarray.flatten((self.y).astype(int)), np.ndarray.flatten((y_pred > 0.5).astype(int)))
#         recall = recall_score(np.ndarray.flatten((self.y).astype(int)), np.ndarray.flatten((y_pred > 0.5).astype(int)))
        
        y_pred_val = self.model.predict(self.x_val)
        roc_val = roc_auc_score(self.y_val, y_pred_val > 0.5)
        prec_val = precision_score(np.ndarray.flatten((self.y_val).astype(int)), np.ndarray.flatten((y_pred_val > 0.5).astype(int)))
        recall_val = recall_score(np.ndarray.flatten((self.y_val).astype(int)), np.ndarray.flatten((y_pred_val > 0.5).astype(int)))
        
        print('\rroc-auc_val: %s' % (str(round(roc_val,4))),end=100*' '+'\n')
        print('\rprecision_val: %s' % (str(round(prec_val,4))),end=100*' '+'\n')
        print('\rrecall_val: %s' % (str(round(recall_val,4))),end=100*' '+'\n')
        
#         print('\rroc-auc: %s - roc-auc_val: %s' % (str(round(roc,4)),str(round(roc_val,4))),end=100*' '+'\n')
#         print('\rprecision: %s - precision_val: %s' % (str(round(prec,4)),str(round(prec_val,4))),end=100*' '+'\n')
#         print('\rrecall: %s - recall_val: %s' % (str(round(recall,4)),str(round(recall_val,4))),end=100*' '+'\n')
        return

    def on_batch_begin(self, batch, logs={}):
        return

    def on_batch_end(self, batch, logs={}):
        return

# %%
# train_inp.shape, train_out.shape


# model.fit( \
#           X_train, \
#           y_train, \
#           validation_data=(X_val, y_val),
#           batch_size=64, \
#           epochs=1000, \
#           callbacks=[metrics(training_data=(X_train, y_train), validation_data=(X_val, y_val))],
#          )

MASK_PROB = 0.15 #@param {type:"number"}
MASK_ERROR_PROB = 0.8 #@param {type:"number"}
BATCH_SIZE = 64 #@param {type:"number"}

tr, val = train_test_split(train[:TRAIN_SIZE], test_size=0.2, shuffle=False)
train_gen = dataset_generator(tr.main_content, MASK_PROB, MASK_ERROR_PROB, batch_size=BATCH_SIZE)
X_val, y_val = next(dataset_generator(val.main_content, MASK_PROB, MASK_ERROR_PROB, batch_size=BATCH_SIZE * 100))

model.fit_generator( \
          train_gen, \
          steps_per_epoch = 1000, \
          validation_data=(X_val, y_val), \
          callbacks=[metrics(validation_data=(X_val, y_val))], \
          epochs=10000,
         )
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_impl.py:112: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/10000
# roc-auc_val: 0.5777
# precision_val: 0.8496
# recall_val: 0.1591
# 1000/1000 [==============================] - 133s 133ms/step - loss: 0.3237 - mean_absolute_error: 0.1852 - acc: 0.8925 - val_loss: 0.3024 - val_mean_absolute_error: 0.1736 - val_acc: 0.8956
# Epoch 2/10000
# roc-auc_val: 0.6405
# precision_val: 0.7439
# recall_val: 0.2947
# 1000/1000 [==============================] - 45s 45ms/step - loss: 0.2811 - mean_absolute_error: 0.1621 - acc: 0.9001 - val_loss: 0.2636 - val_mean_absolute_error: 0.1568 - val_acc: 0.9031
# Epoch 3/10000
# roc-auc_val: 0.6636
# precision_val: 0.7634
# recall_val: 0.3414
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.2538 - mean_absolute_error: 0.1469 - acc: 0.9066 - val_loss: 0.2456 - val_mean_absolute_error: 0.1437 - val_acc: 0.9082
# Epoch 4/10000
# roc-auc_val: 0.6829
# precision_val: 0.7556
# recall_val: 0.3822
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.2407 - mean_absolute_error: 0.1398 - acc: 0.9096 - val_loss: 0.2347 - val_mean_absolute_error: 0.1384 - val_acc: 0.9109
# Epoch 5/10000
# roc-auc_val: 0.6938
# precision_val: 0.7598
# recall_val: 0.4046
# 1000/1000 [==============================] - 41s 41ms/step - loss: 0.2325 - mean_absolute_error: 0.1354 - acc: 0.9116 - val_loss: 0.2280 - val_mean_absolute_error: 0.1350 - val_acc: 0.9131
# Epoch 6/10000
# roc-auc_val: 0.6976
# precision_val: 0.7725
# recall_val: 0.4113
# 1000/1000 [==============================] - 40s 40ms/step - loss: 0.2252 - mean_absolute_error: 0.1314 - acc: 0.9138 - val_loss: 0.2221 - val_mean_absolute_error: 0.1291 - val_acc: 0.9147
# Epoch 7/10000
# roc-auc_val: 0.7009
# precision_val: 0.7853
# recall_val: 0.4168
# 1000/1000 [==============================] - 45s 45ms/step - loss: 0.2201 - mean_absolute_error: 0.1287 - acc: 0.9153 - val_loss: 0.2173 - val_mean_absolute_error: 0.1250 - val_acc: 0.9162
# Epoch 8/10000
# roc-auc_val: 0.7239
# precision_val: 0.7459
# recall_val: 0.4691
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.2153 - mean_absolute_error: 0.1260 - acc: 0.9165 - val_loss: 0.2139 - val_mean_absolute_error: 0.1299 - val_acc: 0.9170
# Epoch 9/10000
# roc-auc_val: 0.7272
# precision_val: 0.7471
# recall_val: 0.4758
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.2119 - mean_absolute_error: 0.1241 - acc: 0.9178 - val_loss: 0.2104 - val_mean_absolute_error: 0.1246 - val_acc: 0.9177
# Epoch 10/10000
# roc-auc_val: 0.7252
# precision_val: 0.7596
# recall_val: 0.4702
# 1000/1000 [==============================] - 41s 41ms/step - loss: 0.2091 - mean_absolute_error: 0.1227 - acc: 0.9184 - val_loss: 0.2077 - val_mean_absolute_error: 0.1244 - val_acc: 0.9185
# Epoch 11/10000
# roc-auc_val: 0.7244
# precision_val: 0.7747
# recall_val: 0.4667
# 1000/1000 [==============================] - 39s 39ms/step - loss: 0.2058 - mean_absolute_error: 0.1209 - acc: 0.9195 - val_loss: 0.2047 - val_mean_absolute_error: 0.1171 - val_acc: 0.9196
# Epoch 12/10000
# roc-auc_val: 0.7292
# precision_val: 0.7709
# recall_val: 0.4772
# 1000/1000 [==============================] - 45s 45ms/step - loss: 0.2030 - mean_absolute_error: 0.1193 - acc: 0.9203 - val_loss: 0.2024 - val_mean_absolute_error: 0.1168 - val_acc: 0.9201
# Epoch 13/10000
# roc-auc_val: 0.7343
# precision_val: 0.7699
# recall_val: 0.4879
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.2021 - mean_absolute_error: 0.1189 - acc: 0.9203 - val_loss: 0.2004 - val_mean_absolute_error: 0.1172 - val_acc: 0.9209
# Epoch 14/10000
# roc-auc_val: 0.7359
# precision_val: 0.7688
# recall_val: 0.4914
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1993 - mean_absolute_error: 0.1174 - acc: 0.9211 - val_loss: 0.1987 - val_mean_absolute_error: 0.1178 - val_acc: 0.9211
# Epoch 15/10000
# roc-auc_val: 0.7388
# precision_val: 0.7736
# recall_val: 0.4969
# 1000/1000 [==============================] - 41s 41ms/step - loss: 0.1980 - mean_absolute_error: 0.1167 - acc: 0.9216 - val_loss: 0.1970 - val_mean_absolute_error: 0.1175 - val_acc: 0.9221
# Epoch 16/10000
# roc-auc_val: 0.7486
# precision_val: 0.759
# recall_val: 0.519
# 1000/1000 [==============================] - 40s 40ms/step - loss: 0.1963 - mean_absolute_error: 0.1157 - acc: 0.9222 - val_loss: 0.1959 - val_mean_absolute_error: 0.1195 - val_acc: 0.9224
# Epoch 17/10000
# roc-auc_val: 0.737
# precision_val: 0.7835
# recall_val: 0.492
# 1000/1000 [==============================] - 45s 45ms/step - loss: 0.1940 - mean_absolute_error: 0.1145 - acc: 0.9229 - val_loss: 0.1950 - val_mean_absolute_error: 0.1112 - val_acc: 0.9226
# Epoch 18/10000
# roc-auc_val: 0.74
# precision_val: 0.7831
# recall_val: 0.4983
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.1936 - mean_absolute_error: 0.1142 - acc: 0.9231 - val_loss: 0.1932 - val_mean_absolute_error: 0.1118 - val_acc: 0.9231
# Epoch 19/10000
# roc-auc_val: 0.7439
# precision_val: 0.778
# recall_val: 0.5067
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.1922 - mean_absolute_error: 0.1135 - acc: 0.9233 - val_loss: 0.1919 - val_mean_absolute_error: 0.1124 - val_acc: 0.9234
# Epoch 20/10000
# roc-auc_val: 0.7563
# precision_val: 0.7587
# recall_val: 0.5353
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1904 - mean_absolute_error: 0.1124 - acc: 0.9241 - val_loss: 0.1910 - val_mean_absolute_error: 0.1143 - val_acc: 0.9237
# Epoch 21/10000
# roc-auc_val: 0.7495
# precision_val: 0.7789
# recall_val: 0.5183
# 1000/1000 [==============================] - 41s 41ms/step - loss: 0.1900 - mean_absolute_error: 0.1123 - acc: 0.9244 - val_loss: 0.1898 - val_mean_absolute_error: 0.1094 - val_acc: 0.9244
# Epoch 22/10000
# roc-auc_val: 0.7399
# precision_val: 0.7973
# recall_val: 0.4964
# 1000/1000 [==============================] - 40s 40ms/step - loss: 0.1885 - mean_absolute_error: 0.1114 - acc: 0.9248 - val_loss: 0.1894 - val_mean_absolute_error: 0.1093 - val_acc: 0.9243
# Epoch 23/10000
# roc-auc_val: 0.744
# precision_val: 0.787
# recall_val: 0.506
# 1000/1000 [==============================] - 39s 39ms/step - loss: 0.1883 - mean_absolute_error: 0.1113 - acc: 0.9248 - val_loss: 0.1896 - val_mean_absolute_error: 0.1083 - val_acc: 0.9242
# Epoch 24/10000
# roc-auc_val: 0.7582
# precision_val: 0.7656
# recall_val: 0.5383
# 1000/1000 [==============================] - 45s 45ms/step - loss: 0.1871 - mean_absolute_error: 0.1106 - acc: 0.9253 - val_loss: 0.1883 - val_mean_absolute_error: 0.1129 - val_acc: 0.9247
# Epoch 25/10000
# roc-auc_val: 0.748
# precision_val: 0.789
# recall_val: 0.514
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.1865 - mean_absolute_error: 0.1102 - acc: 0.9255 - val_loss: 0.1875 - val_mean_absolute_error: 0.1086 - val_acc: 0.9251
# Epoch 26/10000
# roc-auc_val: 0.7482
# precision_val: 0.7907
# recall_val: 0.5142
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1856 - mean_absolute_error: 0.1097 - acc: 0.9258 - val_loss: 0.1866 - val_mean_absolute_error: 0.1073 - val_acc: 0.9253
# Epoch 27/10000
# roc-auc_val: 0.7561
# precision_val: 0.7809
# recall_val: 0.5318
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1851 - mean_absolute_error: 0.1094 - acc: 0.9258 - val_loss: 0.1855 - val_mean_absolute_error: 0.1082 - val_acc: 0.9258
# Epoch 28/10000
# roc-auc_val: 0.762
# precision_val: 0.7746
# recall_val: 0.5448
# 1000/1000 [==============================] - 40s 40ms/step - loss: 0.1842 - mean_absolute_error: 0.1089 - acc: 0.9263 - val_loss: 0.1842 - val_mean_absolute_error: 0.1089 - val_acc: 0.9263
# Epoch 29/10000
# roc-auc_val: 0.75
# precision_val: 0.7866
# recall_val: 0.5186
# 1000/1000 [==============================] - 39s 39ms/step - loss: 0.1843 - mean_absolute_error: 0.1089 - acc: 0.9263 - val_loss: 0.1857 - val_mean_absolute_error: 0.1059 - val_acc: 0.9253
# Epoch 30/10000
# roc-auc_val: 0.7669
# precision_val: 0.7663
# recall_val: 0.5562
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.1831 - mean_absolute_error: 0.1083 - acc: 0.9267 - val_loss: 0.1834 - val_mean_absolute_error: 0.1090 - val_acc: 0.9263
# Epoch 31/10000
# roc-auc_val: 0.7604
# precision_val: 0.7853
# recall_val: 0.5402
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1828 - mean_absolute_error: 0.1081 - acc: 0.9268 - val_loss: 0.1822 - val_mean_absolute_error: 0.1072 - val_acc: 0.9270
# Epoch 32/10000
# roc-auc_val: 0.7644
# precision_val: 0.7771
# recall_val: 0.5498
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1814 - mean_absolute_error: 0.1072 - acc: 0.9272 - val_loss: 0.1824 - val_mean_absolute_error: 0.1096 - val_acc: 0.9270
# Epoch 33/10000
# roc-auc_val: 0.76
# precision_val: 0.7825
# recall_val: 0.5398
# 1000/1000 [==============================] - 41s 41ms/step - loss: 0.1815 - mean_absolute_error: 0.1074 - acc: 0.9273 - val_loss: 0.1819 - val_mean_absolute_error: 0.1063 - val_acc: 0.9267
# Epoch 34/10000
# roc-auc_val: 0.7592
# precision_val: 0.7912
# recall_val: 0.5371
# 1000/1000 [==============================] - 40s 40ms/step - loss: 0.1808 - mean_absolute_error: 0.1070 - acc: 0.9273 - val_loss: 0.1814 - val_mean_absolute_error: 0.1032 - val_acc: 0.9274
# Epoch 35/10000
# roc-auc_val: 0.7572
# precision_val: 0.7951
# recall_val: 0.5322
# 1000/1000 [==============================] - 45s 45ms/step - loss: 0.1803 - mean_absolute_error: 0.1065 - acc: 0.9279 - val_loss: 0.1812 - val_mean_absolute_error: 0.1038 - val_acc: 0.9273
# Epoch 36/10000
# roc-auc_val: 0.7658
# precision_val: 0.7751
# recall_val: 0.5527
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.1800 - mean_absolute_error: 0.1065 - acc: 0.9277 - val_loss: 0.1803 - val_mean_absolute_error: 0.1078 - val_acc: 0.9270
# Epoch 37/10000
# roc-auc_val: 0.7737
# precision_val: 0.767
# recall_val: 0.5703
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1797 - mean_absolute_error: 0.1064 - acc: 0.9277 - val_loss: 0.1802 - val_mean_absolute_error: 0.1082 - val_acc: 0.9276
# Epoch 38/10000
# roc-auc_val: 0.7635
# precision_val: 0.786
# recall_val: 0.5467
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1787 - mean_absolute_error: 0.1056 - acc: 0.9283 - val_loss: 0.1799 - val_mean_absolute_error: 0.1053 - val_acc: 0.9277
# Epoch 39/10000
# roc-auc_val: 0.7708
# precision_val: 0.7705
# recall_val: 0.5638
# 1000/1000 [==============================] - 41s 41ms/step - loss: 0.1783 - mean_absolute_error: 0.1055 - acc: 0.9285 - val_loss: 0.1801 - val_mean_absolute_error: 0.1072 - val_acc: 0.9274
# Epoch 40/10000
# roc-auc_val: 0.7684
# precision_val: 0.7776
# recall_val: 0.5579
# 1000/1000 [==============================] - 40s 40ms/step - loss: 0.1788 - mean_absolute_error: 0.1056 - acc: 0.9283 - val_loss: 0.1787 - val_mean_absolute_error: 0.1047 - val_acc: 0.9277
# Epoch 41/10000
# roc-auc_val: 0.7724
# precision_val: 0.7801
# recall_val: 0.5658
# 1000/1000 [==============================] - 45s 45ms/step - loss: 0.1775 - mean_absolute_error: 0.1049 - acc: 0.9288 - val_loss: 0.1781 - val_mean_absolute_error: 0.1076 - val_acc: 0.9287
# Epoch 42/10000
# roc-auc_val: 0.7701
# precision_val: 0.7731
# recall_val: 0.562
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.1781 - mean_absolute_error: 0.1054 - acc: 0.9284 - val_loss: 0.1785 - val_mean_absolute_error: 0.1076 - val_acc: 0.9276
# Epoch 43/10000
# roc-auc_val: 0.7692
# precision_val: 0.7843
# recall_val: 0.5587
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.1774 - mean_absolute_error: 0.1049 - acc: 0.9288 - val_loss: 0.1776 - val_mean_absolute_error: 0.1038 - val_acc: 0.9285
# Epoch 44/10000
# roc-auc_val: 0.7754
# precision_val: 0.774
# recall_val: 0.5728
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1764 - mean_absolute_error: 0.1043 - acc: 0.9292 - val_loss: 0.1773 - val_mean_absolute_error: 0.1057 - val_acc: 0.9286
# Epoch 45/10000
# roc-auc_val: 0.7661
# precision_val: 0.7915
# recall_val: 0.5512
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1769 - mean_absolute_error: 0.1047 - acc: 0.9289 - val_loss: 0.1773 - val_mean_absolute_error: 0.1034 - val_acc: 0.9286
# Epoch 46/10000
# roc-auc_val: 0.7764
# precision_val: 0.7684
# recall_val: 0.5756
# 1000/1000 [==============================] - 40s 40ms/step - loss: 0.1766 - mean_absolute_error: 0.1043 - acc: 0.9292 - val_loss: 0.1773 - val_mean_absolute_error: 0.1063 - val_acc: 0.9282
# Epoch 47/10000
# roc-auc_val: 0.7742
# precision_val: 0.7794
# recall_val: 0.5696
# 1000/1000 [==============================] - 39s 39ms/step - loss: 0.1763 - mean_absolute_error: 0.1043 - acc: 0.9292 - val_loss: 0.1760 - val_mean_absolute_error: 0.1054 - val_acc: 0.9289
# Epoch 48/10000
# roc-auc_val: 0.768
# precision_val: 0.7872
# recall_val: 0.5557
# 1000/1000 [==============================] - 45s 45ms/step - loss: 0.1755 - mean_absolute_error: 0.1037 - acc: 0.9296 - val_loss: 0.1762 - val_mean_absolute_error: 0.1026 - val_acc: 0.9286
# Epoch 49/10000
# roc-auc_val: 0.7729
# precision_val: 0.7775
# recall_val: 0.567
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.1752 - mean_absolute_error: 0.1037 - acc: 0.9295 - val_loss: 0.1763 - val_mean_absolute_error: 0.1052 - val_acc: 0.9285
# Epoch 50/10000
# roc-auc_val: 0.7678
# precision_val: 0.7939
# recall_val: 0.5544
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1748 - mean_absolute_error: 0.1035 - acc: 0.9295 - val_loss: 0.1756 - val_mean_absolute_error: 0.1026 - val_acc: 0.9292
# Epoch 51/10000
# roc-auc_val: 0.7708
# precision_val: 0.7879
# recall_val: 0.5614
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1744 - mean_absolute_error: 0.1031 - acc: 0.9300 - val_loss: 0.1750 - val_mean_absolute_error: 0.1021 - val_acc: 0.9291
# Epoch 52/10000
# roc-auc_val: 0.7729
# precision_val: 0.7844
# recall_val: 0.5662
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1739 - mean_absolute_error: 0.1030 - acc: 0.9299 - val_loss: 0.1745 - val_mean_absolute_error: 0.1011 - val_acc: 0.9292
# Epoch 53/10000
# roc-auc_val: 0.7718
# precision_val: 0.7901
# recall_val: 0.5632
# 1000/1000 [==============================] - 41s 41ms/step - loss: 0.1739 - mean_absolute_error: 0.1028 - acc: 0.9303 - val_loss: 0.1751 - val_mean_absolute_error: 0.1030 - val_acc: 0.9295
# Epoch 54/10000
# roc-auc_val: 0.7704
# precision_val: 0.7828
# recall_val: 0.5613
# 1000/1000 [==============================] - 40s 40ms/step - loss: 0.1746 - mean_absolute_error: 0.1032 - acc: 0.9299 - val_loss: 0.1749 - val_mean_absolute_error: 0.1027 - val_acc: 0.9286
# Epoch 55/10000
# roc-auc_val: 0.7706
# precision_val: 0.7926
# recall_val: 0.5605
# 1000/1000 [==============================] - 39s 39ms/step - loss: 0.1738 - mean_absolute_error: 0.1028 - acc: 0.9302 - val_loss: 0.1747 - val_mean_absolute_error: 0.1012 - val_acc: 0.9296
# Epoch 56/10000
# roc-auc_val: 0.7811
# precision_val: 0.7708
# recall_val: 0.5852
# 1000/1000 [==============================] - 45s 45ms/step - loss: 0.1735 - mean_absolute_error: 0.1026 - acc: 0.9302 - val_loss: 0.1745 - val_mean_absolute_error: 0.1038 - val_acc: 0.9293
# Epoch 57/10000
# roc-auc_val: 0.7811
# precision_val: 0.7801
# recall_val: 0.5839
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.1734 - mean_absolute_error: 0.1026 - acc: 0.9301 - val_loss: 0.1737 - val_mean_absolute_error: 0.1022 - val_acc: 0.9302
# Epoch 58/10000
# roc-auc_val: 0.7858
# precision_val: 0.7676
# recall_val: 0.5954
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1733 - mean_absolute_error: 0.1025 - acc: 0.9302 - val_loss: 0.1737 - val_mean_absolute_error: 0.1043 - val_acc: 0.9297
# Epoch 59/10000
# roc-auc_val: 0.7757
# precision_val: 0.7864
# recall_val: 0.5718
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1726 - mean_absolute_error: 0.1020 - acc: 0.9308 - val_loss: 0.1732 - val_mean_absolute_error: 0.1024 - val_acc: 0.9299
# Epoch 60/10000
# roc-auc_val: 0.7773
# precision_val: 0.7848
# recall_val: 0.5752
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1728 - mean_absolute_error: 0.1022 - acc: 0.9304 - val_loss: 0.1733 - val_mean_absolute_error: 0.1020 - val_acc: 0.9300
# Epoch 61/10000
# roc-auc_val: 0.7791
# precision_val: 0.7758
# recall_val: 0.5804
# 1000/1000 [==============================] - 40s 40ms/step - loss: 0.1724 - mean_absolute_error: 0.1020 - acc: 0.9306 - val_loss: 0.1738 - val_mean_absolute_error: 0.1028 - val_acc: 0.9294
# Epoch 62/10000
# roc-auc_val: 0.7774
# precision_val: 0.7813
# recall_val: 0.5761
# 1000/1000 [==============================] - 39s 39ms/step - loss: 0.1720 - mean_absolute_error: 0.1017 - acc: 0.9309 - val_loss: 0.1732 - val_mean_absolute_error: 0.1009 - val_acc: 0.9297
# Epoch 63/10000
# roc-auc_val: 0.7852
# precision_val: 0.7691
# recall_val: 0.594
# 1000/1000 [==============================] - 45s 45ms/step - loss: 0.1728 - mean_absolute_error: 0.1023 - acc: 0.9302 - val_loss: 0.1729 - val_mean_absolute_error: 0.1042 - val_acc: 0.9298
# Epoch 64/10000
# roc-auc_val: 0.7801
# precision_val: 0.7806
# recall_val: 0.5818
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.1713 - mean_absolute_error: 0.1013 - acc: 0.9311 - val_loss: 0.1728 - val_mean_absolute_error: 0.1036 - val_acc: 0.9301
# Epoch 65/10000
# roc-auc_val: 0.775
# precision_val: 0.7939
# recall_val: 0.5694
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1717 - mean_absolute_error: 0.1015 - acc: 0.9311 - val_loss: 0.1718 - val_mean_absolute_error: 0.1013 - val_acc: 0.9305
# Epoch 66/10000
# roc-auc_val: 0.7832
# precision_val: 0.7759
# recall_val: 0.5888
# 1000/1000 [==============================] - 41s 41ms/step - loss: 0.1724 - mean_absolute_error: 0.1020 - acc: 0.9305 - val_loss: 0.1728 - val_mean_absolute_error: 0.1031 - val_acc: 0.9302
# Epoch 67/10000
# roc-auc_val: 0.7776
# precision_val: 0.7861
# recall_val: 0.5757
# 1000/1000 [==============================] - 40s 40ms/step - loss: 0.1714 - mean_absolute_error: 0.1014 - acc: 0.9310 - val_loss: 0.1721 - val_mean_absolute_error: 0.1013 - val_acc: 0.9302
# Epoch 68/10000
# roc-auc_val: 0.7758
# precision_val: 0.7919
# recall_val: 0.5713
# 1000/1000 [==============================] - 40s 40ms/step - loss: 0.1710 - mean_absolute_error: 0.1012 - acc: 0.9311 - val_loss: 0.1718 - val_mean_absolute_error: 0.1022 - val_acc: 0.9304
# Epoch 69/10000
# roc-auc_val: 0.7802
# precision_val: 0.7872
# recall_val: 0.581
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.1706 - mean_absolute_error: 0.1008 - acc: 0.9312 - val_loss: 0.1720 - val_mean_absolute_error: 0.1039 - val_acc: 0.9308
# Epoch 70/10000
# roc-auc_val: 0.7893
# precision_val: 0.7672
# recall_val: 0.6028
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1704 - mean_absolute_error: 0.1008 - acc: 0.9314 - val_loss: 0.1721 - val_mean_absolute_error: 0.1024 - val_acc: 0.9303
# Epoch 71/10000
# roc-auc_val: 0.7817
# precision_val: 0.7859
# recall_val: 0.5844
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1705 - mean_absolute_error: 0.1009 - acc: 0.9313 - val_loss: 0.1719 - val_mean_absolute_error: 0.0996 - val_acc: 0.9309
# Epoch 72/10000
# roc-auc_val: 0.7817
# precision_val: 0.7832
# recall_val: 0.5846
# 1000/1000 [==============================] - 41s 41ms/step - loss: 0.1704 - mean_absolute_error: 0.1008 - acc: 0.9314 - val_loss: 0.1713 - val_mean_absolute_error: 0.1018 - val_acc: 0.9306
# Epoch 73/10000
# roc-auc_val: 0.7862
# precision_val: 0.7765
# recall_val: 0.595
# 1000/1000 [==============================] - 40s 40ms/step - loss: 0.1705 - mean_absolute_error: 0.1008 - acc: 0.9315 - val_loss: 0.1709 - val_mean_absolute_error: 0.1016 - val_acc: 0.9308
# Epoch 74/10000
# roc-auc_val: 0.7778
# precision_val: 0.7904
# recall_val: 0.5756
# 1000/1000 [==============================] - 39s 39ms/step - loss: 0.1708 - mean_absolute_error: 0.1009 - acc: 0.9313 - val_loss: 0.1710 - val_mean_absolute_error: 0.1009 - val_acc: 0.9307
# Epoch 75/10000
# roc-auc_val: 0.7916
# precision_val: 0.7707
# recall_val: 0.6069
# 1000/1000 [==============================] - 45s 45ms/step - loss: 0.1711 - mean_absolute_error: 0.1012 - acc: 0.9311 - val_loss: 0.1703 - val_mean_absolute_error: 0.1026 - val_acc: 0.9311
# Epoch 76/10000
# roc-auc_val: 0.7885
# precision_val: 0.7707
# recall_val: 0.6004
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1700 - mean_absolute_error: 0.1006 - acc: 0.9314 - val_loss: 0.1711 - val_mean_absolute_error: 0.1035 - val_acc: 0.9305
# Epoch 77/10000
# roc-auc_val: 0.7833
# precision_val: 0.7883
# recall_val: 0.5872
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1694 - mean_absolute_error: 0.1001 - acc: 0.9319 - val_loss: 0.1699 - val_mean_absolute_error: 0.1005 - val_acc: 0.9315
# Epoch 78/10000
# roc-auc_val: 0.7954
# precision_val: 0.7608
# recall_val: 0.6165
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1692 - mean_absolute_error: 0.1000 - acc: 0.9319 - val_loss: 0.1711 - val_mean_absolute_error: 0.1034 - val_acc: 0.9306
# Epoch 79/10000
# roc-auc_val: 0.7888
# precision_val: 0.7734
# recall_val: 0.6009
# 1000/1000 [==============================] - 40s 40ms/step - loss: 0.1695 - mean_absolute_error: 0.1003 - acc: 0.9316 - val_loss: 0.1697 - val_mean_absolute_error: 0.1008 - val_acc: 0.9309
# Epoch 80/10000
# roc-auc_val: 0.787
# precision_val: 0.7818
# recall_val: 0.5958
# 1000/1000 [==============================] - 39s 39ms/step - loss: 0.1692 - mean_absolute_error: 0.1001 - acc: 0.9317 - val_loss: 0.1699 - val_mean_absolute_error: 0.1008 - val_acc: 0.9315
# Epoch 81/10000
# roc-auc_val: 0.784
# precision_val: 0.7869
# recall_val: 0.5889
# 1000/1000 [==============================] - 45s 45ms/step - loss: 0.1694 - mean_absolute_error: 0.1001 - acc: 0.9318 - val_loss: 0.1695 - val_mean_absolute_error: 0.1001 - val_acc: 0.9314
# Epoch 82/10000
# roc-auc_val: 0.7936
# precision_val: 0.7679
# recall_val: 0.6117
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.1696 - mean_absolute_error: 0.1004 - acc: 0.9318 - val_loss: 0.1700 - val_mean_absolute_error: 0.1016 - val_acc: 0.9311
# Epoch 83/10000
# roc-auc_val: 0.7825
# precision_val: 0.7896
# recall_val: 0.5855
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1693 - mean_absolute_error: 0.1002 - acc: 0.9315 - val_loss: 0.1695 - val_mean_absolute_error: 0.0990 - val_acc: 0.9315
# Epoch 84/10000
# roc-auc_val: 0.7988
# precision_val: 0.7651
# recall_val: 0.6228
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1689 - mean_absolute_error: 0.0998 - acc: 0.9320 - val_loss: 0.1694 - val_mean_absolute_error: 0.1025 - val_acc: 0.9317
# Epoch 85/10000
# roc-auc_val: 0.7946
# precision_val: 0.7705
# recall_val: 0.6133
# 1000/1000 [==============================] - 41s 41ms/step - loss: 0.1688 - mean_absolute_error: 0.0997 - acc: 0.9322 - val_loss: 0.1692 - val_mean_absolute_error: 0.1025 - val_acc: 0.9316
# Epoch 86/10000
# roc-auc_val: 0.784
# precision_val: 0.7919
# recall_val: 0.5883
# 1000/1000 [==============================] - 40s 40ms/step - loss: 0.1686 - mean_absolute_error: 0.0997 - acc: 0.9319 - val_loss: 0.1686 - val_mean_absolute_error: 0.0995 - val_acc: 0.9320
# Epoch 87/10000
# roc-auc_val: 0.7877
# precision_val: 0.7787
# recall_val: 0.5978
# 1000/1000 [==============================] - 39s 39ms/step - loss: 0.1684 - mean_absolute_error: 0.0996 - acc: 0.9322 - val_loss: 0.1692 - val_mean_absolute_error: 0.1013 - val_acc: 0.9313
# Epoch 88/10000
# roc-auc_val: 0.7889
# precision_val: 0.7807
# recall_val: 0.5998
# 1000/1000 [==============================] - 45s 45ms/step - loss: 0.1686 - mean_absolute_error: 0.0997 - acc: 0.9320 - val_loss: 0.1691 - val_mean_absolute_error: 0.1007 - val_acc: 0.9317
# Epoch 89/10000
# roc-auc_val: 0.7798
# precision_val: 0.7938
# recall_val: 0.5794
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.1676 - mean_absolute_error: 0.0990 - acc: 0.9327 - val_loss: 0.1692 - val_mean_absolute_error: 0.0984 - val_acc: 0.9314
# Epoch 90/10000
# roc-auc_val: 0.784
# precision_val: 0.787
# recall_val: 0.5888
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1678 - mean_absolute_error: 0.0992 - acc: 0.9323 - val_loss: 0.1693 - val_mean_absolute_error: 0.0985 - val_acc: 0.9314
# Epoch 91/10000
# roc-auc_val: 0.7875
# precision_val: 0.7848
# recall_val: 0.5965
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1677 - mean_absolute_error: 0.0991 - acc: 0.9325 - val_loss: 0.1690 - val_mean_absolute_error: 0.0990 - val_acc: 0.9319
# Epoch 92/10000
# roc-auc_val: 0.7827
# precision_val: 0.792
# recall_val: 0.5854
# 1000/1000 [==============================] - 40s 40ms/step - loss: 0.1673 - mean_absolute_error: 0.0989 - acc: 0.9328 - val_loss: 0.1688 - val_mean_absolute_error: 0.0991 - val_acc: 0.9317
# Epoch 93/10000
# roc-auc_val: 0.7836
# precision_val: 0.7915
# recall_val: 0.5875
# 1000/1000 [==============================] - 39s 39ms/step - loss: 0.1681 - mean_absolute_error: 0.0994 - acc: 0.9324 - val_loss: 0.1687 - val_mean_absolute_error: 0.0982 - val_acc: 0.9318
# Epoch 94/10000
# roc-auc_val: 0.79
# precision_val: 0.7799
# recall_val: 0.6022
# 1000/1000 [==============================] - 45s 45ms/step - loss: 0.1674 - mean_absolute_error: 0.0990 - acc: 0.9326 - val_loss: 0.1685 - val_mean_absolute_error: 0.0997 - val_acc: 0.9318
# Epoch 95/10000
# roc-auc_val: 0.797
# precision_val: 0.765
# recall_val: 0.619
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1674 - mean_absolute_error: 0.0990 - acc: 0.9326 - val_loss: 0.1695 - val_mean_absolute_error: 0.1028 - val_acc: 0.9314
# Epoch 96/10000
# roc-auc_val: 0.7852
# precision_val: 0.7867
# recall_val: 0.5915
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1676 - mean_absolute_error: 0.0991 - acc: 0.9326 - val_loss: 0.1690 - val_mean_absolute_error: 0.1002 - val_acc: 0.9317
# Epoch 97/10000
# roc-auc_val: 0.7954
# precision_val: 0.7666
# recall_val: 0.6155
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1677 - mean_absolute_error: 0.0992 - acc: 0.9323 - val_loss: 0.1695 - val_mean_absolute_error: 0.1016 - val_acc: 0.9313
# Epoch 98/10000
# roc-auc_val: 0.7897
# precision_val: 0.7736
# recall_val: 0.6025
# 1000/1000 [==============================] - 41s 41ms/step - loss: 0.1671 - mean_absolute_error: 0.0987 - acc: 0.9328 - val_loss: 0.1691 - val_mean_absolute_error: 0.1000 - val_acc: 0.9311
# Epoch 99/10000
# roc-auc_val: 0.7794
# precision_val: 0.799
# recall_val: 0.5779
# 1000/1000 [==============================] - 40s 40ms/step - loss: 0.1668 - mean_absolute_error: 0.0985 - acc: 0.9330 - val_loss: 0.1694 - val_mean_absolute_error: 0.0970 - val_acc: 0.9318
# Epoch 100/10000
# roc-auc_val: 0.7863
# precision_val: 0.7866
# recall_val: 0.5937
# 1000/1000 [==============================] - 40s 40ms/step - loss: 0.1668 - mean_absolute_error: 0.0987 - acc: 0.9327 - val_loss: 0.1682 - val_mean_absolute_error: 0.1016 - val_acc: 0.9318
# Epoch 101/10000
# roc-auc_val: 0.7829
# precision_val: 0.7963
# recall_val: 0.5853
# 1000/1000 [==============================] - 45s 45ms/step - loss: 0.1672 - mean_absolute_error: 0.0988 - acc: 0.9328 - val_loss: 0.1677 - val_mean_absolute_error: 0.0980 - val_acc: 0.9322
# Epoch 102/10000
# roc-auc_val: 0.7896
# precision_val: 0.7816
# recall_val: 0.6012
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.1669 - mean_absolute_error: 0.0986 - acc: 0.9329 - val_loss: 0.1685 - val_mean_absolute_error: 0.1005 - val_acc: 0.9319
# Epoch 103/10000
# roc-auc_val: 0.7845
# precision_val: 0.7934
# recall_val: 0.589
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1670 - mean_absolute_error: 0.0988 - acc: 0.9326 - val_loss: 0.1675 - val_mean_absolute_error: 0.0986 - val_acc: 0.9322
# Epoch 104/10000
# roc-auc_val: 0.7866
# precision_val: 0.7807
# recall_val: 0.5952
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1670 - mean_absolute_error: 0.0987 - acc: 0.9328 - val_loss: 0.1685 - val_mean_absolute_error: 0.0995 - val_acc: 0.9313
# Epoch 105/10000
# roc-auc_val: 0.7838
# precision_val: 0.7908
# recall_val: 0.588
# 1000/1000 [==============================] - 41s 41ms/step - loss: 0.1672 - mean_absolute_error: 0.0988 - acc: 0.9328 - val_loss: 0.1681 - val_mean_absolute_error: 0.0973 - val_acc: 0.9318
# Epoch 106/10000
# roc-auc_val: 0.7825
# precision_val: 0.7964
# recall_val: 0.5845
# 1000/1000 [==============================] - 40s 40ms/step - loss: 0.1658 - mean_absolute_error: 0.0981 - acc: 0.9331 - val_loss: 0.1680 - val_mean_absolute_error: 0.0972 - val_acc: 0.9321
# Epoch 107/10000
#  427/1000 [===========>..................] - ETA: 20s - loss: 0.1654 - mean_absolute_error: 0.0978 - acc: 0.9333
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-d5bcd2917a2a> in <module>()
#       8 X_val, y_val = next(dataset_generator(val.main_content, MASK_PROB, MASK_ERROR_PROB, batch_size=BATCH_SIZE * 100))
#       9
# ---> 10 model.fit_generator(           train_gen,           steps_per_epoch = 1000,           validation_data=(X_val, y_val),           callbacks=[metrics(validation_data=(X_val, y_val))],           epochs=10000,
#      11          )
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2175         use_multiprocessing=use_multiprocessing,
#    2176         shuffle=shuffle,
# -> 2177         initial_epoch=initial_epoch)
#    2178
#    2179   def evaluate_generator(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     174
#     175         outs = model.train_on_batch(
# --> 176             x, y, sample_weight=sample_weight, class_weight=class_weight)
#     177
#     178         if not isinstance(outs, list):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1938
#    1939       self._make_train_function()
# -> 1940       outputs = self.train_function(ins)
#    1941
#    1942     if len(outputs) == 1:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    2984
#    2985     fetched = self._callable_fn(*array_vals,
# -> 2986                                 run_metadata=self.run_metadata)
#    2987     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    2988     return fetched[:len(self.outputs)]
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
test_gen = dataset_generator(test[:1].main_content, MASK_PROB, MASK_ERROR_PROB, batch_size=BATCH_SIZE)

# %%
test_inp, test_out = next(test_gen)
test_pred = model.predict(test_inp)

# %%
visualize(test_inp, test_out, test_pred)

# %%
raw_test_gen = dataset_generator(test[:100].main_content, mask_prob=0., mask_error_prob=0., batch_size=BATCH_SIZE)

# %%
raw_test_inp, raw_test_out = next(raw_test_gen)
raw_test_pred = model.predict(raw_test_inp)

visualize(raw_test_inp, raw_test_out, raw_test_pred, display_rows=5)

# %%
# Improvement
# Better corpus
# Masked Loss Function (?)
# Pretrainined Word Vector (done)
# Better Typo Models
# Tune precision threshold
# Concat Char Level pretrainined word vectors
# Dropout and Regularization
# Random error probability per sentence
