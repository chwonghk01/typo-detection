# %%
# !pip install --upgrade pyarrow
# !git clone https://github.com/facebookresearch/fastText.git
# !cd fastText && pip install .
# Out:
# Collecting pyarrow
#   Downloading https://files.pythonhosted.org/packages/36/94/23135312f97b20d6457294606fb70fad43ef93b7bffe567088ebe3623703/pyarrow-0.11.1-cp36-cp36m-manylinux1_x86_64.whl (11.6MB)
#     100% |████████████████████████████████| 11.6MB 4.0MB/s
# Requirement already satisfied, skipping upgrade: numpy>=1.14 in /usr/local/lib/python3.6/dist-packages (from pyarrow) (1.14.6)
# Requirement already satisfied, skipping upgrade: six>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from pyarrow) (1.11.0)
# Installing collected packages: pyarrow
# Successfully installed pyarrow-0.11.1
# Cloning into 'fastText'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 2784 (delta 3), reused 8 (delta 3), pack-reused 2771
# Receiving objects: 100% (2784/2784), 7.68 MiB | 29.80 MiB/s, done.
# Resolving deltas: 100% (1750/1750), done.
# Processing /content/fastText
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.6/dist-packages (from fasttext==0.8.22) (2.2.4)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from fasttext==0.8.22) (40.6.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fasttext==0.8.22) (1.14.6)
# Building wheels for collected packages: fasttext
# done
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gncevtau/wheels/a1/9f/52/696ce6c5c46325e840c76614ee5051458c0df10306987e7443
# Successfully built fasttext
# Installing collected packages: fasttext
# Successfully installed fasttext-0.8.22

# %%
# !wget https://www.wfonts.com/download/data/2014/06/01/simhei/simhei.zip
# !unzip simhei.zip
# !wget https://s3-us-west-1.amazonaws.com/fasttext-vectors/wiki.zh_classical.zip
# !unzip wiki.zh_classical.zip
# Out:
# --2018-12-18 01:56:49--  https://www.wfonts.com/download/data/2014/06/01/simhei/simhei.zip
# Resolving www.wfonts.com (www.wfonts.com)... 104.225.219.210
# Connecting to www.wfonts.com (www.wfonts.com)|104.225.219.210|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10546298 (10M) [application/octetstream]
# Saving to: ‘simhei.zip’
#
# simhei.zip          100%[===================>]  10.06M  18.1MB/s    in 0.6s
#
# 2018-12-18 01:56:50 (18.1 MB/s) - ‘simhei.zip’ saved [10546298/10546298]
#
# Archive:  simhei.zip
#   inflating: chinese.simhei.ttf
#   inflating: SimHei.ttf
#   inflating: sharefonts.net.txt
# --2018-12-18 01:56:53--  https://s3-us-west-1.amazonaws.com/fasttext-vectors/wiki.zh_classical.zip
# Resolving s3-us-west-1.amazonaws.com (s3-us-west-1.amazonaws.com)... 52.219.24.49
# Connecting to s3-us-west-1.amazonaws.com (s3-us-west-1.amazonaws.com)|52.219.24.49|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2253991999 (2.1G) [application/zip]
# Saving to: ‘wiki.zh_classical.zip’
#
# wiki.zh_classical.z 100%[===================>]   2.10G  62.0MB/s    in 37s
#
# 2018-12-18 01:57:30 (58.6 MB/s) - ‘wiki.zh_classical.zip’ saved [2253991999/2253991999]
#
# Archive:  wiki.zh_classical.zip
#   inflating: wiki.zh_classical.vec
#   inflating: wiki.zh_classical.bin

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import models
from sklearn.model_selection import train_test_split
import numpy as np
import fastText

print(tf.VERSION)
print(tf.keras.__version__)
# Out:
# 1.12.0
# 2.1.6-tf

# %%
df = pd.read_parquet('/gdrive/My Drive/typo-detection/article_contents.snappy.parquet')[['article_id', 'main_content']].set_index('article_id')
df = df[~df.main_content.isnull()]
df.head()
# Out:
#                                                  main_content
# article_id
# 3           英超曼聯今晨主場出擊，只能與剛剛上任為車路士的領隊軒迪克打和0:0，近8場未嘗勝績，備受批評...
# 6           港超勁旅南華宣布羅致前厄瓜多爾國腳菲力斯保耶（Felix Borja），簽約一年半；足主張廣...
# 7           阿仙奴走出日前慘吞修咸頓4球的陰影，今晨主場憑奧斯爾一傳一射，以2：0氣走般尼茅夫，以19戰...
# 9           英超今晨其餘賽事，熱刺憑前鋒孫興愍89分鐘的入球，以２：1作客反勝屈福特，暫時升上聯賽榜第3...
# 10          352場英超上陣，170場不失球，令阿仙奴門將施治打破前英格蘭國腳占士紀錄，成為英超史上不失...

# %%
# Train test split articles
train, test = train_test_split(df, test_size=0.2, shuffle=False)
train.shape, test.shape
# Out:
# ((174664, 1), (43667, 1))

# %%
TRAIN_SIZE = -1
TEST_SIZE = -1

# Run tokenizer on char level for training data, support 100k + tokens, with oov token (from keras)
tokenizer = tf.keras.preprocessing.text.Tokenizer(char_level=True, oov_token='<oov>', split='')
tokenizer.fit_on_texts(train[:TRAIN_SIZE].main_content)
len(tokenizer.index_word), tokenizer.word_index['<oov>']
# Out:
# (12496, 1)

# %%
# Split article to 64 chars each for both training and testing
# Keras Articles -> Chars -> Indices -> Pad to 64 chars

SEQ_LENGTH = 32 #@param {type:"integer"}

# def generate_dataset(df, error_prob):
#   seqs = tokenizer.texts_to_sequences(df.main_content)
#   padded_seqs = tf.keras.preprocessing.sequence.pad_sequences(seqs, maxlen=SEQ_LENGTH, padding='post', truncating='post', value=0.0)
  
#   index_word_count = [(tokenizer.word_index[k], v) for k, v in tokenizer.word_counts.items()]
#   index_word_count.append((0, sum([x[1] for x in index_word_count]) / (error_prob) * (1 - error_prob)))
  
#   choice = np.array([x[0] for x in index_word_count])

#   p = np.array([x[1] for x in index_word_count])
#   p = p / np.sum(p)
  
#   # for each sequence, randomly replace the index
#   random_error = np.random.choice(choice, padded_seqs.shape, p=p)
#   random_error_mask = (random_error > 0).astype(int)
  
#   inp = padded_seqs * (1-random_error_mask) + random_error
#   out = random_error_mask
  
#   return inp, out


# TODO: fully utilize corpus insteads of only first 32 tokens
def dataset_generator(corpus, mask_prob=0.15, mask_error_prob=0.8, batch_size=64, seed=42):
  seqs = tokenizer.texts_to_sequences(corpus)
  
  def chunk(list_of_list, chunk_size): 
    result = []
    for l in list_of_list:
      for i in range(len(l) // chunk_size):
        result.append(l[i*chunk_size:i*chunk_size+chunk_size])

    return result
  
  seqs = chunk(seqs, chunk_size=SEQ_LENGTH)
  padded_seqs = tf.keras.preprocessing.sequence.pad_sequences(seqs, maxlen=SEQ_LENGTH, padding='post', truncating='post', value=0.0)
  
  # Create FIXED mask for each full dataset
  masks = np.random.choice([0., 1.,], padded_seqs.shape, p=np.array([1-mask_prob, mask_prob]))
  
  # Word choice by count frequency
  index_word_count = [(tokenizer.word_index[k], v) for k, v in tokenizer.word_counts.items()]
  choice = np.array([x[0] for x in index_word_count])
  p = np.array([x[1] for x in index_word_count])
  p = p / np.sum(p)

  
  # Uniformly random sample a batch of (padded_seq, mask)
  while True:
    idx = np.random.randint(padded_seqs.shape[0], size=batch_size)
    inp = padded_seqs[idx]
    out = masks[idx]
    
    # replace each masked token by 1-mask_error_prob the original word, mask_error_prob a randomly sampled word
    out = out * np.random.choice([0., 1.,], out.shape, p=np.array([1-mask_error_prob, mask_error_prob]))
    
    random_error = np.random.choice(choice, inp.shape, p=p)
    inp = inp * (1-out) + random_error * out
    
    yield (inp, out)

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import font_manager
import numpy as np
import seaborn as sns

def visualize(inp, truth, pred=None, display_rows=5):
  font_files = font_manager.findSystemFonts(fontpaths='/content')
  font_list = font_manager.createFontList(font_files)
  font_manager.fontManager.ttflist.extend(font_list)
  sns.set_style("darkgrid",{"font.sans-serif":['simhei', 'Arial']})

  fig, ax = plt.subplots(figsize=(24 * SEQ_LENGTH // 64,display_rows / 3))
  sns.heatmap(truth[:display_rows], \
    annot=np.array([[c for c in row[::2]] for row in tokenizer.sequences_to_texts(inp)[:display_rows]]), \
    fmt='', cmap="YlGnBu", ax=ax, vmin=0, vmax=1)
  
  if pred is not None:
    fig, ax = plt.subplots(figsize=(24 * SEQ_LENGTH // 64,display_rows / 3))
    sns.heatmap(pred[:display_rows], \
      annot=np.array([[c for c in row[::2]] for row in tokenizer.sequences_to_texts(inp)[:display_rows]]), \
      fmt='', cmap="YlGnBu", ax=ax, vmin=0, vmax=1)

# %%
# tokenizer.index_word
ft = fastText.load_model('./wiki.zh_classical.bin')

FT_EMB_SIZE = 300

fasttext_emb = np.zeros((len(tokenizer.index_word) + 1, FT_EMB_SIZE))
for idx, word in tokenizer.index_word.items():
  fasttext_emb[idx] = ft.get_word_vector(word)
  
fasttext_emb[:5]
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 1.96946334e-04,  1.22728362e-03, -2.59545923e-04, ...,
#          6.70105277e-04, -2.94898928e-04,  2.82796507e-04],
#        [ 9.10380185e-02, -5.44981882e-02, -3.35275382e-02, ...,
#         -1.62986919e-01, -1.13570802e-01,  9.72174481e-02],
#        [-1.56043924e-03, -3.07246787e-03, -2.24617636e-03, ...,
#         -3.23857740e-03,  8.81240587e-04, -6.76950789e-04],
#        [ 1.48805141e-01,  7.97280390e-03, -5.96142173e-01, ...,
#          1.35237249e-02,  4.78576571e-02,  4.08989703e-03]])

# %%
EMBEDDING_SIZE = 64 #@param {type:"integer"}
GRU_SIZE = EMBEDDING_SIZE // 2
  
def build_model():
#   model = models.Sequential()
  inp = layers.Input((SEQ_LENGTH,), dtype='int32')
  emb = layers.Embedding(len(tokenizer.index_word) + 1, EMBEDDING_SIZE, input_length=SEQ_LENGTH)(inp)
  
  ft_emb = layers.Embedding(len(tokenizer.index_word) + 1, FT_EMB_SIZE, weights=[fasttext_emb], trainable=False, input_length=SEQ_LENGTH)(inp)
  
  emb_input = layers.Concatenate()([emb, ft_emb])
  
  gru = layers.Bidirectional(layers.CuDNNGRU(GRU_SIZE, return_sequences=True))(emb_input)
  gru = layers.Bidirectional(layers.CuDNNGRU(GRU_SIZE, return_sequences=True))(gru)
  
  final = layers.Add()([gru, emb])
#   gru = layers.CuDNNGRU(GRU_SIZE, return_sequences=True)(gru)
  
  pred = layers.Dense(1, activation='sigmoid')(final)
  out = layers.Flatten()(pred)
  
  model = models.Model(inputs=inp, outputs=out)
  model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['mae', 'acc'])
  return model
  
model = build_model()
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32)           0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 32, 64)       799808      input_1[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 32, 300)      3749100     input_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 364)      0           embedding[0][0]
#                                                                  embedding_1[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 32, 64)       76416       concatenate[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 32, 64)       18816       bidirectional[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 64)       0           bidirectional_1[0][0]
#                                                                  embedding[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32, 1)        65          add[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 32)           0           dense[0][0]
# ==================================================================================================
# Total params: 4,644,205
# Trainable params: 895,105
# Non-trainable params: 3,749,100
# __________________________________________________________________________________________________

# %%
from sklearn.metrics import roc_auc_score, precision_score, recall_score
from tensorflow.keras.callbacks import Callback

class metrics(Callback):
    def __init__(self, validation_data):
#         self.x = training_data[0]
#         self.y = training_data[1]
        self.x_val = validation_data[0]
        self.y_val = validation_data[1]


    def on_train_begin(self, logs={}):
        return

    def on_train_end(self, logs={}):
        return

    def on_epoch_begin(self, epoch, logs={}):
        return

    def on_epoch_end(self, epoch, logs={}):
#         y_pred = self.model.predict(self.x)
#         roc = roc_auc_score(self.y, y_pred)
#         prec = precision_score(np.ndarray.flatten((self.y).astype(int)), np.ndarray.flatten((y_pred > 0.5).astype(int)))
#         recall = recall_score(np.ndarray.flatten((self.y).astype(int)), np.ndarray.flatten((y_pred > 0.5).astype(int)))
        
        y_pred_val = self.model.predict(self.x_val)
        roc_val = roc_auc_score(self.y_val, y_pred_val > 0.5)
        prec_val = precision_score(np.ndarray.flatten((self.y_val).astype(int)), np.ndarray.flatten((y_pred_val > 0.5).astype(int)))
        recall_val = recall_score(np.ndarray.flatten((self.y_val).astype(int)), np.ndarray.flatten((y_pred_val > 0.5).astype(int)))
        
        print('\rroc-auc_val: %s' % (str(round(roc_val,4))),end=100*' '+'\n')
        print('\rprecision_val: %s' % (str(round(prec_val,4))),end=100*' '+'\n')
        print('\rrecall_val: %s' % (str(round(recall_val,4))),end=100*' '+'\n')
        
#         print('\rroc-auc: %s - roc-auc_val: %s' % (str(round(roc,4)),str(round(roc_val,4))),end=100*' '+'\n')
#         print('\rprecision: %s - precision_val: %s' % (str(round(prec,4)),str(round(prec_val,4))),end=100*' '+'\n')
#         print('\rrecall: %s - recall_val: %s' % (str(round(recall,4)),str(round(recall_val,4))),end=100*' '+'\n')
        return

    def on_batch_begin(self, batch, logs={}):
        return

    def on_batch_end(self, batch, logs={}):
        return

# %%
# train_inp.shape, train_out.shape


# model.fit( \
#           X_train, \
#           y_train, \
#           validation_data=(X_val, y_val),
#           batch_size=64, \
#           epochs=1000, \
#           callbacks=[metrics(training_data=(X_train, y_train), validation_data=(X_val, y_val))],
#          )

MASK_PROB = 0.15 #@param {type:"number"}
MASK_ERROR_PROB = 0.8 #@param {type:"number"}
BATCH_SIZE = 64 #@param {type:"number"}

tr, val = train_test_split(train[:TRAIN_SIZE], test_size=0.2, shuffle=False)
train_gen = dataset_generator(tr.main_content, MASK_PROB, MASK_ERROR_PROB, batch_size=BATCH_SIZE)
X_val, y_val = next(dataset_generator(val.main_content, MASK_PROB, MASK_ERROR_PROB, batch_size=BATCH_SIZE * 100))

model.fit_generator( \
          train_gen, \
          steps_per_epoch = 1000, \
          validation_data=(X_val, y_val), \
          callbacks=[metrics(validation_data=(X_val, y_val))], \
          epochs=10000,
         )
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_impl.py:112: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/10000
# roc-auc_val: 0.5807
# precision_val: 0.8017
# recall_val: 0.1673
# 1000/1000 [==============================] - 129s 129ms/step - loss: 0.3317 - mean_absolute_error: 0.1900 - acc: 0.8910 - val_loss: 0.3109 - val_mean_absolute_error: 0.1769 - val_acc: 0.8943
# Epoch 2/10000
# roc-auc_val: 0.6123
# precision_val: 0.7723
# recall_val: 0.2343
# 1000/1000 [==============================] - 37s 37ms/step - loss: 0.2983 - mean_absolute_error: 0.1716 - acc: 0.8967 - val_loss: 0.2823 - val_mean_absolute_error: 0.1626 - val_acc: 0.8990
# Epoch 3/10000
# roc-auc_val: 0.6407
# precision_val: 0.7537
# recall_val: 0.2949
# 1000/1000 [==============================] - 36s 36ms/step - loss: 0.2717 - mean_absolute_error: 0.1573 - acc: 0.9016 - val_loss: 0.2634 - val_mean_absolute_error: 0.1551 - val_acc: 0.9031
# Epoch 4/10000
# roc-auc_val: 0.6519
# precision_val: 0.7625
# recall_val: 0.3174
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.2573 - mean_absolute_error: 0.1493 - acc: 0.9051 - val_loss: 0.2553 - val_mean_absolute_error: 0.1445 - val_acc: 0.9055
# Epoch 5/10000
# roc-auc_val: 0.6516
# precision_val: 0.7845
# recall_val: 0.3153
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.2489 - mean_absolute_error: 0.1446 - acc: 0.9071 - val_loss: 0.2478 - val_mean_absolute_error: 0.1369 - val_acc: 0.9067
# Epoch 6/10000
# roc-auc_val: 0.673
# precision_val: 0.7508
# recall_val: 0.3627
# 1000/1000 [==============================] - 34s 34ms/step - loss: 0.2426 - mean_absolute_error: 0.1413 - acc: 0.9087 - val_loss: 0.2400 - val_mean_absolute_error: 0.1391 - val_acc: 0.9084
# Epoch 7/10000
# roc-auc_val: 0.6859
# precision_val: 0.744
# recall_val: 0.3904
# 1000/1000 [==============================] - 36s 36ms/step - loss: 0.2365 - mean_absolute_error: 0.1379 - acc: 0.9104 - val_loss: 0.2356 - val_mean_absolute_error: 0.1405 - val_acc: 0.9100
# Epoch 8/10000
# roc-auc_val: 0.6739
# precision_val: 0.7849
# recall_val: 0.3616
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.2335 - mean_absolute_error: 0.1363 - acc: 0.9110 - val_loss: 0.2316 - val_mean_absolute_error: 0.1318 - val_acc: 0.9108
# Epoch 9/10000
# roc-auc_val: 0.6967
# precision_val: 0.7432
# recall_val: 0.4133
# 1000/1000 [==============================] - 34s 34ms/step - loss: 0.2289 - mean_absolute_error: 0.1339 - acc: 0.9122 - val_loss: 0.2284 - val_mean_absolute_error: 0.1366 - val_acc: 0.9118
# Epoch 10/10000
# roc-auc_val: 0.6711
# precision_val: 0.8053
# recall_val: 0.3541
# 1000/1000 [==============================] - 37s 37ms/step - loss: 0.2251 - mean_absolute_error: 0.1318 - acc: 0.9134 - val_loss: 0.2276 - val_mean_absolute_error: 0.1250 - val_acc: 0.9115
# Epoch 11/10000
# roc-auc_val: 0.703
# precision_val: 0.7454
# recall_val: 0.4262
# 1000/1000 [==============================] - 36s 36ms/step - loss: 0.2229 - mean_absolute_error: 0.1308 - acc: 0.9135 - val_loss: 0.2229 - val_mean_absolute_error: 0.1324 - val_acc: 0.9130
# Epoch 12/10000
# roc-auc_val: 0.7002
# precision_val: 0.7619
# recall_val: 0.4185
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.2198 - mean_absolute_error: 0.1288 - acc: 0.9150 - val_loss: 0.2208 - val_mean_absolute_error: 0.1267 - val_acc: 0.9139
# Epoch 13/10000
# roc-auc_val: 0.702
# precision_val: 0.7602
# recall_val: 0.4224
# 1000/1000 [==============================] - 34s 34ms/step - loss: 0.2185 - mean_absolute_error: 0.1283 - acc: 0.9150 - val_loss: 0.2181 - val_mean_absolute_error: 0.1284 - val_acc: 0.9140
# Epoch 14/10000
# roc-auc_val: 0.7119
# precision_val: 0.7505
# recall_val: 0.4442
# 1000/1000 [==============================] - 37s 37ms/step - loss: 0.2162 - mean_absolute_error: 0.1271 - acc: 0.9155 - val_loss: 0.2157 - val_mean_absolute_error: 0.1312 - val_acc: 0.9149
# Epoch 15/10000
# roc-auc_val: 0.7019
# precision_val: 0.7774
# recall_val: 0.4204
# 1000/1000 [==============================] - 36s 36ms/step - loss: 0.2149 - mean_absolute_error: 0.1264 - acc: 0.9159 - val_loss: 0.2140 - val_mean_absolute_error: 0.1231 - val_acc: 0.9153
# Epoch 16/10000
# roc-auc_val: 0.7149
# precision_val: 0.7568
# recall_val: 0.4498
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.2114 - mean_absolute_error: 0.1245 - acc: 0.9170 - val_loss: 0.2124 - val_mean_absolute_error: 0.1223 - val_acc: 0.9160
# Epoch 17/10000
# roc-auc_val: 0.7094
# precision_val: 0.771
# recall_val: 0.4366
# 1000/1000 [==============================] - 34s 34ms/step - loss: 0.2111 - mean_absolute_error: 0.1244 - acc: 0.9170 - val_loss: 0.2111 - val_mean_absolute_error: 0.1240 - val_acc: 0.9162
# Epoch 18/10000
# roc-auc_val: 0.715
# precision_val: 0.7644
# recall_val: 0.4491
# 1000/1000 [==============================] - 37s 37ms/step - loss: 0.2093 - mean_absolute_error: 0.1235 - acc: 0.9173 - val_loss: 0.2092 - val_mean_absolute_error: 0.1222 - val_acc: 0.9166
# Epoch 19/10000
# roc-auc_val: 0.7151
# precision_val: 0.7721
# recall_val: 0.4484
# 1000/1000 [==============================] - 36s 36ms/step - loss: 0.2081 - mean_absolute_error: 0.1228 - acc: 0.9179 - val_loss: 0.2078 - val_mean_absolute_error: 0.1205 - val_acc: 0.9173
# Epoch 20/10000
# roc-auc_val: 0.7279
# precision_val: 0.7556
# recall_val: 0.4772
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.2067 - mean_absolute_error: 0.1220 - acc: 0.9181 - val_loss: 0.2068 - val_mean_absolute_error: 0.1235 - val_acc: 0.9181
# Epoch 21/10000
# roc-auc_val: 0.72
# precision_val: 0.7702
# recall_val: 0.4589
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.2064 - mean_absolute_error: 0.1220 - acc: 0.9182 - val_loss: 0.2063 - val_mean_absolute_error: 0.1178 - val_acc: 0.9180
# Epoch 22/10000
# roc-auc_val: 0.7361
# precision_val: 0.7425
# recall_val: 0.4959
# 1000/1000 [==============================] - 37s 37ms/step - loss: 0.2047 - mean_absolute_error: 0.1209 - acc: 0.9189 - val_loss: 0.2049 - val_mean_absolute_error: 0.1236 - val_acc: 0.9182
# Epoch 23/10000
# roc-auc_val: 0.7255
# precision_val: 0.7636
# recall_val: 0.4712
# 1000/1000 [==============================] - 36s 36ms/step - loss: 0.2037 - mean_absolute_error: 0.1204 - acc: 0.9193 - val_loss: 0.2043 - val_mean_absolute_error: 0.1201 - val_acc: 0.9184
# Epoch 24/10000
# roc-auc_val: 0.7411
# precision_val: 0.7421
# recall_val: 0.5066
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.2027 - mean_absolute_error: 0.1199 - acc: 0.9193 - val_loss: 0.2035 - val_mean_absolute_error: 0.1227 - val_acc: 0.9190
# Epoch 25/10000
# roc-auc_val: 0.7345
# precision_val: 0.7542
# recall_val: 0.4912
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.2030 - mean_absolute_error: 0.1201 - acc: 0.9192 - val_loss: 0.2027 - val_mean_absolute_error: 0.1209 - val_acc: 0.9191
# Epoch 26/10000
# roc-auc_val: 0.7235
# precision_val: 0.7719
# recall_val: 0.4662
# 1000/1000 [==============================] - 37s 37ms/step - loss: 0.2013 - mean_absolute_error: 0.1192 - acc: 0.9195 - val_loss: 0.2026 - val_mean_absolute_error: 0.1168 - val_acc: 0.9188
# Epoch 27/10000
# roc-auc_val: 0.7363
# precision_val: 0.758
# recall_val: 0.4943
# 1000/1000 [==============================] - 36s 36ms/step - loss: 0.2014 - mean_absolute_error: 0.1193 - acc: 0.9197 - val_loss: 0.2004 - val_mean_absolute_error: 0.1196 - val_acc: 0.9198
# Epoch 28/10000
# roc-auc_val: 0.7412
# precision_val: 0.7474
# recall_val: 0.5059
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.2001 - mean_absolute_error: 0.1186 - acc: 0.9200 - val_loss: 0.2005 - val_mean_absolute_error: 0.1178 - val_acc: 0.9196
# Epoch 29/10000
# roc-auc_val: 0.7332
# precision_val: 0.7692
# recall_val: 0.4867
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.1992 - mean_absolute_error: 0.1180 - acc: 0.9204 - val_loss: 0.1987 - val_mean_absolute_error: 0.1189 - val_acc: 0.9203
# Epoch 30/10000
# roc-auc_val: 0.7301
# precision_val: 0.7748
# recall_val: 0.4795
# 1000/1000 [==============================] - 37s 37ms/step - loss: 0.1987 - mean_absolute_error: 0.1177 - acc: 0.9207 - val_loss: 0.1988 - val_mean_absolute_error: 0.1162 - val_acc: 0.9202
# Epoch 31/10000
# roc-auc_val: 0.7275
# precision_val: 0.7837
# recall_val: 0.473
# 1000/1000 [==============================] - 36s 36ms/step - loss: 0.1985 - mean_absolute_error: 0.1176 - acc: 0.9206 - val_loss: 0.1978 - val_mean_absolute_error: 0.1165 - val_acc: 0.9205
# Epoch 32/10000
# roc-auc_val: 0.7346
# precision_val: 0.774
# recall_val: 0.4891
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.1975 - mean_absolute_error: 0.1170 - acc: 0.9211 - val_loss: 0.1969 - val_mean_absolute_error: 0.1163 - val_acc: 0.9209
# Epoch 33/10000
# roc-auc_val: 0.7261
# precision_val: 0.7902
# recall_val: 0.4695
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.1964 - mean_absolute_error: 0.1163 - acc: 0.9217 - val_loss: 0.1974 - val_mean_absolute_error: 0.1129 - val_acc: 0.9208
# Epoch 34/10000
# roc-auc_val: 0.7492
# precision_val: 0.7443
# recall_val: 0.5233
# 1000/1000 [==============================] - 37s 37ms/step - loss: 0.1967 - mean_absolute_error: 0.1166 - acc: 0.9211 - val_loss: 0.1968 - val_mean_absolute_error: 0.1200 - val_acc: 0.9206
# Epoch 35/10000
# roc-auc_val: 0.7347
# precision_val: 0.7735
# recall_val: 0.4893
# 1000/1000 [==============================] - 36s 36ms/step - loss: 0.1961 - mean_absolute_error: 0.1162 - acc: 0.9216 - val_loss: 0.1962 - val_mean_absolute_error: 0.1142 - val_acc: 0.9209
# Epoch 36/10000
# roc-auc_val: 0.7406
# precision_val: 0.7634
# recall_val: 0.5028
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.1957 - mean_absolute_error: 0.1161 - acc: 0.9216 - val_loss: 0.1956 - val_mean_absolute_error: 0.1155 - val_acc: 0.9210
# Epoch 37/10000
# roc-auc_val: 0.7404
# precision_val: 0.767
# recall_val: 0.5019
# 1000/1000 [==============================] - 34s 34ms/step - loss: 0.1951 - mean_absolute_error: 0.1157 - acc: 0.9219 - val_loss: 0.1956 - val_mean_absolute_error: 0.1130 - val_acc: 0.9213
# Epoch 38/10000
# roc-auc_val: 0.7344
# precision_val: 0.7759
# recall_val: 0.4884
# 1000/1000 [==============================] - 37s 37ms/step - loss: 0.1940 - mean_absolute_error: 0.1149 - acc: 0.9222 - val_loss: 0.1949 - val_mean_absolute_error: 0.1169 - val_acc: 0.9211
# Epoch 39/10000
# roc-auc_val: 0.7322
# precision_val: 0.7819
# recall_val: 0.4831
# 1000/1000 [==============================] - 36s 36ms/step - loss: 0.1937 - mean_absolute_error: 0.1149 - acc: 0.9222 - val_loss: 0.1948 - val_mean_absolute_error: 0.1129 - val_acc: 0.9212
# Epoch 40/10000
# roc-auc_val: 0.7481
# precision_val: 0.7633
# recall_val: 0.5184
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.1930 - mean_absolute_error: 0.1144 - acc: 0.9226 - val_loss: 0.1931 - val_mean_absolute_error: 0.1163 - val_acc: 0.9223
# Epoch 41/10000
# roc-auc_val: 0.7403
# precision_val: 0.7736
# recall_val: 0.501
# 1000/1000 [==============================] - 34s 34ms/step - loss: 0.1934 - mean_absolute_error: 0.1147 - acc: 0.9224 - val_loss: 0.1938 - val_mean_absolute_error: 0.1147 - val_acc: 0.9219
# Epoch 42/10000
# roc-auc_val: 0.7343
# precision_val: 0.7859
# recall_val: 0.487
# 1000/1000 [==============================] - 37s 37ms/step - loss: 0.1931 - mean_absolute_error: 0.1145 - acc: 0.9225 - val_loss: 0.1933 - val_mean_absolute_error: 0.1137 - val_acc: 0.9219
# Epoch 43/10000
# roc-auc_val: 0.754
# precision_val: 0.7543
# recall_val: 0.532
# 1000/1000 [==============================] - 36s 36ms/step - loss: 0.1927 - mean_absolute_error: 0.1143 - acc: 0.9225 - val_loss: 0.1926 - val_mean_absolute_error: 0.1168 - val_acc: 0.9224
# Epoch 44/10000
# roc-auc_val: 0.7535
# precision_val: 0.7515
# recall_val: 0.5314
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.1922 - mean_absolute_error: 0.1141 - acc: 0.9226 - val_loss: 0.1927 - val_mean_absolute_error: 0.1177 - val_acc: 0.9221
# Epoch 45/10000
# roc-auc_val: 0.749
# precision_val: 0.7641
# recall_val: 0.5202
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.1918 - mean_absolute_error: 0.1138 - acc: 0.9231 - val_loss: 0.1923 - val_mean_absolute_error: 0.1159 - val_acc: 0.9226
# Epoch 46/10000
# roc-auc_val: 0.7413
# precision_val: 0.7706
# recall_val: 0.5034
# 1000/1000 [==============================] - 37s 37ms/step - loss: 0.1918 - mean_absolute_error: 0.1139 - acc: 0.9227 - val_loss: 0.1934 - val_mean_absolute_error: 0.1132 - val_acc: 0.9218
# Epoch 47/10000
# roc-auc_val: 0.7502
# precision_val: 0.7637
# recall_val: 0.5228
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.1918 - mean_absolute_error: 0.1140 - acc: 0.9225 - val_loss: 0.1914 - val_mean_absolute_error: 0.1136 - val_acc: 0.9227
# Epoch 48/10000
# roc-auc_val: 0.759
# precision_val: 0.752
# recall_val: 0.5428
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.1916 - mean_absolute_error: 0.1139 - acc: 0.9228 - val_loss: 0.1908 - val_mean_absolute_error: 0.1152 - val_acc: 0.9231
# Epoch 49/10000
# roc-auc_val: 0.7465
# precision_val: 0.7757
# recall_val: 0.5135
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.1906 - mean_absolute_error: 0.1131 - acc: 0.9233 - val_loss: 0.1906 - val_mean_absolute_error: 0.1146 - val_acc: 0.9232
# Epoch 50/10000
# roc-auc_val: 0.7488
# precision_val: 0.7688
# recall_val: 0.5192
# 1000/1000 [==============================] - 37s 37ms/step - loss: 0.1910 - mean_absolute_error: 0.1134 - acc: 0.9231 - val_loss: 0.1902 - val_mean_absolute_error: 0.1132 - val_acc: 0.9230
# Epoch 51/10000
# roc-auc_val: 0.7459
# precision_val: 0.7771
# recall_val: 0.5121
# 1000/1000 [==============================] - 36s 36ms/step - loss: 0.1894 - mean_absolute_error: 0.1124 - acc: 0.9236 - val_loss: 0.1905 - val_mean_absolute_error: 0.1119 - val_acc: 0.9232
# Epoch 52/10000
# roc-auc_val: 0.7492
# precision_val: 0.7684
# recall_val: 0.5202
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.1897 - mean_absolute_error: 0.1126 - acc: 0.9235 - val_loss: 0.1903 - val_mean_absolute_error: 0.1114 - val_acc: 0.9230
# Epoch 53/10000
# roc-auc_val: 0.7481
# precision_val: 0.7762
# recall_val: 0.5168
# 1000/1000 [==============================] - 34s 34ms/step - loss: 0.1894 - mean_absolute_error: 0.1124 - acc: 0.9236 - val_loss: 0.1898 - val_mean_absolute_error: 0.1129 - val_acc: 0.9235
# Epoch 54/10000
# roc-auc_val: 0.757
# precision_val: 0.7626
# recall_val: 0.5371
# 1000/1000 [==============================] - 36s 36ms/step - loss: 0.1890 - mean_absolute_error: 0.1123 - acc: 0.9238 - val_loss: 0.1890 - val_mean_absolute_error: 0.1146 - val_acc: 0.9238
# Epoch 55/10000
# roc-auc_val: 0.762
# precision_val: 0.7479
# recall_val: 0.5496
# 1000/1000 [==============================] - 36s 36ms/step - loss: 0.1893 - mean_absolute_error: 0.1124 - acc: 0.9237 - val_loss: 0.1894 - val_mean_absolute_error: 0.1134 - val_acc: 0.9231
# Epoch 56/10000
# roc-auc_val: 0.7504
# precision_val: 0.7717
# recall_val: 0.5221
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.1891 - mean_absolute_error: 0.1123 - acc: 0.9237 - val_loss: 0.1887 - val_mean_absolute_error: 0.1120 - val_acc: 0.9235
# Epoch 57/10000
# roc-auc_val: 0.7491
# precision_val: 0.7781
# recall_val: 0.5188
# 1000/1000 [==============================] - 34s 34ms/step - loss: 0.1882 - mean_absolute_error: 0.1117 - acc: 0.9240 - val_loss: 0.1885 - val_mean_absolute_error: 0.1118 - val_acc: 0.9239
# Epoch 58/10000
# roc-auc_val: 0.7594
# precision_val: 0.7563
# recall_val: 0.5429
# 1000/1000 [==============================] - 37s 37ms/step - loss: 0.1882 - mean_absolute_error: 0.1117 - acc: 0.9241 - val_loss: 0.1897 - val_mean_absolute_error: 0.1163 - val_acc: 0.9236
# Epoch 59/10000
# roc-auc_val: 0.7566
# precision_val: 0.7564
# recall_val: 0.5371
# 1000/1000 [==============================] - 36s 36ms/step - loss: 0.1890 - mean_absolute_error: 0.1123 - acc: 0.9237 - val_loss: 0.1892 - val_mean_absolute_error: 0.1133 - val_acc: 0.9231
# Epoch 60/10000
# roc-auc_val: 0.7586
# precision_val: 0.7664
# recall_val: 0.54
# 1000/1000 [==============================] - 34s 34ms/step - loss: 0.1877 - mean_absolute_error: 0.1113 - acc: 0.9244 - val_loss: 0.1873 - val_mean_absolute_error: 0.1114 - val_acc: 0.9245
# Epoch 61/10000
# roc-auc_val: 0.7583
# precision_val: 0.7612
# recall_val: 0.54
# 1000/1000 [==============================] - 34s 34ms/step - loss: 0.1880 - mean_absolute_error: 0.1117 - acc: 0.9242 - val_loss: 0.1878 - val_mean_absolute_error: 0.1112 - val_acc: 0.9239
# Epoch 62/10000
# roc-auc_val: 0.7535
# precision_val: 0.7734
# recall_val: 0.5286
# 1000/1000 [==============================] - 37s 37ms/step - loss: 0.1870 - mean_absolute_error: 0.1111 - acc: 0.9245 - val_loss: 0.1871 - val_mean_absolute_error: 0.1124 - val_acc: 0.9243
# Epoch 63/10000
# roc-auc_val: 0.7553
# precision_val: 0.7665
# recall_val: 0.533
# 1000/1000 [==============================] - 36s 36ms/step - loss: 0.1870 - mean_absolute_error: 0.1111 - acc: 0.9243 - val_loss: 0.1875 - val_mean_absolute_error: 0.1125 - val_acc: 0.9239
# Epoch 64/10000
# roc-auc_val: 0.7519
# precision_val: 0.7717
# recall_val: 0.5253
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.1884 - mean_absolute_error: 0.1119 - acc: 0.9241 - val_loss: 0.1875 - val_mean_absolute_error: 0.1110 - val_acc: 0.9238
# Epoch 65/10000
# roc-auc_val: 0.7487
# precision_val: 0.7814
# recall_val: 0.5173
# 1000/1000 [==============================] - 34s 34ms/step - loss: 0.1872 - mean_absolute_error: 0.1112 - acc: 0.9244 - val_loss: 0.1876 - val_mean_absolute_error: 0.1105 - val_acc: 0.9241
# Epoch 66/10000
# roc-auc_val: 0.7571
# precision_val: 0.7638
# recall_val: 0.5372
# 1000/1000 [==============================] - 37s 37ms/step - loss: 0.1864 - mean_absolute_error: 0.1107 - acc: 0.9248 - val_loss: 0.1878 - val_mean_absolute_error: 0.1098 - val_acc: 0.9239
# Epoch 67/10000
#  815/1000 [=======================>......] - ETA: 6s - loss: 0.1863 - mean_absolute_error: 0.1106 - acc: 0.9250
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-f40712a13ae9> in <module>()
#       8 X_val, y_val = next(dataset_generator(val.main_content, MASK_PROB, MASK_ERROR_PROB, batch_size=BATCH_SIZE * 100))
#       9
# ---> 10 model.fit_generator(           train_gen,           steps_per_epoch = 1000,           validation_data=(X_val, y_val),           callbacks=[metrics(validation_data=(X_val, y_val))],           epochs=10000,
#      11          )
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2175         use_multiprocessing=use_multiprocessing,
#    2176         shuffle=shuffle,
# -> 2177         initial_epoch=initial_epoch)
#    2178
#    2179   def evaluate_generator(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     174
#     175         outs = model.train_on_batch(
# --> 176             x, y, sample_weight=sample_weight, class_weight=class_weight)
#     177
#     178         if not isinstance(outs, list):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1938
#    1939       self._make_train_function()
# -> 1940       outputs = self.train_function(ins)
#    1941
#    1942     if len(outputs) == 1:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    2984
#    2985     fetched = self._callable_fn(*array_vals,
# -> 2986                                 run_metadata=self.run_metadata)
#    2987     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    2988     return fetched[:len(self.outputs)]
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
test_gen = dataset_generator(test[:1].main_content, MASK_PROB, MASK_ERROR_PROB, batch_size=BATCH_SIZE)

# %%
test_inp, test_out = next(test_gen)
test_pred = model.predict(test_inp)

# %%
visualize(test_inp, test_out, test_pred)

# %%
raw_test_gen = dataset_generator(test[:100].main_content, mask_prob=0., mask_error_prob=0., batch_size=BATCH_SIZE)

# %%
raw_test_inp, raw_test_out = next(raw_test_gen)
raw_test_pred = model.predict(raw_test_inp)

visualize(raw_test_inp, raw_test_out, raw_test_pred, display_rows=5)

# %%
# Improvement
# Better corpus
# Masked Loss Function (?)
# Pretrainined Word Vector (done)
# Better Typo Models
# Tune precision threshold
# Concat Char Level pretrainined word vectors
# Dropout and Regularization
