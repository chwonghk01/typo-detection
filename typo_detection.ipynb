# %%
# !pip install --upgrade pyarrow
# !git clone https://github.com/facebookresearch/fastText.git
# !cd fastText && pip install .
# Out:
# Collecting pyarrow
#   Downloading https://files.pythonhosted.org/packages/36/94/23135312f97b20d6457294606fb70fad43ef93b7bffe567088ebe3623703/pyarrow-0.11.1-cp36-cp36m-manylinux1_x86_64.whl (11.6MB)
#     100% |████████████████████████████████| 11.6MB 4.0MB/s
# Requirement already satisfied, skipping upgrade: numpy>=1.14 in /usr/local/lib/python3.6/dist-packages (from pyarrow) (1.14.6)
# Requirement already satisfied, skipping upgrade: six>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from pyarrow) (1.11.0)
# Installing collected packages: pyarrow
# Successfully installed pyarrow-0.11.1
# Cloning into 'fastText'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 2784 (delta 3), reused 8 (delta 3), pack-reused 2771
# Receiving objects: 100% (2784/2784), 7.68 MiB | 29.80 MiB/s, done.
# Resolving deltas: 100% (1750/1750), done.
# Processing /content/fastText
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.6/dist-packages (from fasttext==0.8.22) (2.2.4)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from fasttext==0.8.22) (40.6.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fasttext==0.8.22) (1.14.6)
# Building wheels for collected packages: fasttext
# done
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gncevtau/wheels/a1/9f/52/696ce6c5c46325e840c76614ee5051458c0df10306987e7443
# Successfully built fasttext
# Installing collected packages: fasttext
# Successfully installed fasttext-0.8.22

# %%
# !wget https://www.wfonts.com/download/data/2014/06/01/simhei/simhei.zip
# !unzip simhei.zip
# !wget https://s3-us-west-1.amazonaws.com/fasttext-vectors/wiki.zh_classical.zip
# !unzip wiki.zh_classical.zip
# Out:
# --2018-12-18 01:56:49--  https://www.wfonts.com/download/data/2014/06/01/simhei/simhei.zip
# Resolving www.wfonts.com (www.wfonts.com)... 104.225.219.210
# Connecting to www.wfonts.com (www.wfonts.com)|104.225.219.210|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10546298 (10M) [application/octetstream]
# Saving to: ‘simhei.zip’
#
# simhei.zip          100%[===================>]  10.06M  18.1MB/s    in 0.6s
#
# 2018-12-18 01:56:50 (18.1 MB/s) - ‘simhei.zip’ saved [10546298/10546298]
#
# Archive:  simhei.zip
#   inflating: chinese.simhei.ttf
#   inflating: SimHei.ttf
#   inflating: sharefonts.net.txt
# --2018-12-18 01:56:53--  https://s3-us-west-1.amazonaws.com/fasttext-vectors/wiki.zh_classical.zip
# Resolving s3-us-west-1.amazonaws.com (s3-us-west-1.amazonaws.com)... 52.219.24.49
# Connecting to s3-us-west-1.amazonaws.com (s3-us-west-1.amazonaws.com)|52.219.24.49|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2253991999 (2.1G) [application/zip]
# Saving to: ‘wiki.zh_classical.zip’
#
# wiki.zh_classical.z 100%[===================>]   2.10G  62.0MB/s    in 37s
#
# 2018-12-18 01:57:30 (58.6 MB/s) - ‘wiki.zh_classical.zip’ saved [2253991999/2253991999]
#
# Archive:  wiki.zh_classical.zip
#   inflating: wiki.zh_classical.vec
#   inflating: wiki.zh_classical.bin

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import models
from sklearn.model_selection import train_test_split
import numpy as np
import fastText

print(tf.VERSION)
print(tf.keras.__version__)
# Out:
# 1.12.0
# 2.1.6-tf

# %%
df = pd.read_parquet('/gdrive/My Drive/typo-detection/article_contents.snappy.parquet')[['article_id', 'main_content']].set_index('article_id')
df = df[~df.main_content.isnull()]
df.head()
# Out:
#                                                  main_content
# article_id
# 3           英超曼聯今晨主場出擊，只能與剛剛上任為車路士的領隊軒迪克打和0:0，近8場未嘗勝績，備受批評...
# 6           港超勁旅南華宣布羅致前厄瓜多爾國腳菲力斯保耶（Felix Borja），簽約一年半；足主張廣...
# 7           阿仙奴走出日前慘吞修咸頓4球的陰影，今晨主場憑奧斯爾一傳一射，以2：0氣走般尼茅夫，以19戰...
# 9           英超今晨其餘賽事，熱刺憑前鋒孫興愍89分鐘的入球，以２：1作客反勝屈福特，暫時升上聯賽榜第3...
# 10          352場英超上陣，170場不失球，令阿仙奴門將施治打破前英格蘭國腳占士紀錄，成為英超史上不失...

# %%
# Train test split articles
train, test = train_test_split(df, test_size=0.2, shuffle=False)
train.shape, test.shape
# Out:
# ((174664, 1), (43667, 1))

# %%
TRAIN_SIZE = -1
TEST_SIZE = -1

# Run tokenizer on char level for training data, support 100k + tokens, with oov token (from keras)
tokenizer = tf.keras.preprocessing.text.Tokenizer(char_level=True, oov_token='<oov>', split='')
tokenizer.fit_on_texts(train[:TRAIN_SIZE].main_content)
len(tokenizer.index_word), tokenizer.word_index['<oov>']
# Out:
# (12496, 1)

# %%
# Split article to 64 chars each for both training and testing
# Keras Articles -> Chars -> Indices -> Pad to 64 chars

SEQ_LENGTH = 32 #@param {type:"integer"}

# def generate_dataset(df, error_prob):
#   seqs = tokenizer.texts_to_sequences(df.main_content)
#   padded_seqs = tf.keras.preprocessing.sequence.pad_sequences(seqs, maxlen=SEQ_LENGTH, padding='post', truncating='post', value=0.0)
  
#   index_word_count = [(tokenizer.word_index[k], v) for k, v in tokenizer.word_counts.items()]
#   index_word_count.append((0, sum([x[1] for x in index_word_count]) / (error_prob) * (1 - error_prob)))
  
#   choice = np.array([x[0] for x in index_word_count])

#   p = np.array([x[1] for x in index_word_count])
#   p = p / np.sum(p)
  
#   # for each sequence, randomly replace the index
#   random_error = np.random.choice(choice, padded_seqs.shape, p=p)
#   random_error_mask = (random_error > 0).astype(int)
  
#   inp = padded_seqs * (1-random_error_mask) + random_error
#   out = random_error_mask
  
#   return inp, out


# TODO: fully utilize corpus insteads of only first 32 tokens
def dataset_generator(corpus, mask_prob=0.15, mask_error_prob=0.8, batch_size=64, seed=42):
  seqs = tokenizer.texts_to_sequences(corpus)
  
  def chunk(list_of_list, chunk_size): 
    result = []
    for l in list_of_list:
      for i in range(len(l) // chunk_size):
        result.append(l[i*chunk_size:i*chunk_size+chunk_size])

    return result
  
  seqs = chunk(seqs, chunk_size=SEQ_LENGTH)
  padded_seqs = tf.keras.preprocessing.sequence.pad_sequences(seqs, maxlen=SEQ_LENGTH, padding='post', truncating='post', value=0.0)
  
  # Create FIXED mask for each full dataset
  masks = np.random.choice([0., 1.,], padded_seqs.shape, p=np.array([1-mask_prob, mask_prob]))
  
  # Word choice by count frequency
  index_word_count = [(tokenizer.word_index[k], v) for k, v in tokenizer.word_counts.items()]
  choice = np.array([x[0] for x in index_word_count])
  p = np.array([x[1] for x in index_word_count])
  p = p / np.sum(p)

  
  # Uniformly random sample a batch of (padded_seq, mask)
  while True:
    idx = np.random.randint(padded_seqs.shape[0], size=batch_size)
    inp = padded_seqs[idx]
    out = masks[idx]
    
    # replace each masked token by 1-mask_error_prob the original word, mask_error_prob a randomly sampled word
    out = out * np.random.choice([0., 1.,], out.shape, p=np.array([1-mask_error_prob, mask_error_prob]))
    
    random_error = np.random.choice(choice, inp.shape, p=p)
    inp = inp * (1-out) + random_error * out
    
    yield (inp, out)

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import font_manager
import numpy as np
import seaborn as sns

def visualize(inp, truth, pred=None, display_rows=5):
  font_files = font_manager.findSystemFonts(fontpaths='/content')
  font_list = font_manager.createFontList(font_files)
  font_manager.fontManager.ttflist.extend(font_list)
  sns.set_style("darkgrid",{"font.sans-serif":['simhei', 'Arial']})

  fig, ax = plt.subplots(figsize=(24 * SEQ_LENGTH // 64,display_rows / 3))
  sns.heatmap(truth[:display_rows], \
    annot=np.array([[c for c in row[::2]] for row in tokenizer.sequences_to_texts(inp)[:display_rows]]), \
    fmt='', cmap="YlGnBu", ax=ax, vmin=0, vmax=1)
  
  if pred is not None:
    fig, ax = plt.subplots(figsize=(24 * SEQ_LENGTH // 64,display_rows / 3))
    sns.heatmap(pred[:display_rows], \
      annot=np.array([[c for c in row[::2]] for row in tokenizer.sequences_to_texts(inp)[:display_rows]]), \
      fmt='', cmap="YlGnBu", ax=ax, vmin=0, vmax=1)

# %%
# tokenizer.index_word
ft = fastText.load_model('./wiki.zh_classical.bin')

FT_EMB_SIZE = 300

fasttext_emb = np.zeros((len(tokenizer.index_word) + 1, FT_EMB_SIZE))
for idx, word in tokenizer.index_word.items():
  fasttext_emb[idx] = ft.get_word_vector(word)
  
fasttext_emb[:5]
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 1.96946334e-04,  1.22728362e-03, -2.59545923e-04, ...,
#          6.70105277e-04, -2.94898928e-04,  2.82796507e-04],
#        [ 9.10380185e-02, -5.44981882e-02, -3.35275382e-02, ...,
#         -1.62986919e-01, -1.13570802e-01,  9.72174481e-02],
#        [-1.56043924e-03, -3.07246787e-03, -2.24617636e-03, ...,
#         -3.23857740e-03,  8.81240587e-04, -6.76950789e-04],
#        [ 1.48805141e-01,  7.97280390e-03, -5.96142173e-01, ...,
#          1.35237249e-02,  4.78576571e-02,  4.08989703e-03]])

# %%
EMBEDDING_SIZE = 256 #@param {type:"integer"}
GRU_SIZE = EMBEDDING_SIZE // 2
  
def build_model():
#   model = models.Sequential()
  inp = layers.Input((SEQ_LENGTH,), dtype='int32')
  emb = layers.Embedding(len(tokenizer.index_word) + 1, EMBEDDING_SIZE, input_length=SEQ_LENGTH)(inp)
  
#   ft_emb = layers.Embedding(len(tokenizer.index_word) + 1, FT_EMB_SIZE, weights=[fasttext_emb], trainable=False, input_length=SEQ_LENGTH)(inp)

  emb_input = emb
#   emb_input = layers.Concatenate()([emb, ft_emb])
  
  gru = layers.Bidirectional(layers.CuDNNGRU(GRU_SIZE, return_sequences=True))(emb_input)
  gru = layers.Bidirectional(layers.CuDNNGRU(GRU_SIZE, return_sequences=True))(gru)
  
  final = layers.Add()([gru, emb])
#   gru = layers.CuDNNGRU(GRU_SIZE, return_sequences=True)(gru)
  
  pred = layers.Dense(1, activation='sigmoid')(final)
  out = layers.Flatten()(pred)
  
  model = models.Model(inputs=inp, outputs=out)
  model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['mae', 'acc'])
  return model
  
model = build_model()
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 32)           0
# __________________________________________________________________________________________________
# embedding_8 (Embedding)         (None, 32, 256)      3199232     input_5[0][0]
# __________________________________________________________________________________________________
# bidirectional_9 (Bidirectional) (None, 32, 256)      296448      embedding_8[0][0]
# __________________________________________________________________________________________________
# bidirectional_10 (Bidirectional (None, 32, 256)      296448      bidirectional_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 32, 256)      0           bidirectional_10[0][0]
#                                                                  embedding_8[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 32, 1)        257         add_4[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 32)           0           dense_4[0][0]
# ==================================================================================================
# Total params: 3,792,385
# Trainable params: 3,792,385
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from sklearn.metrics import roc_auc_score, precision_score, recall_score
from tensorflow.keras.callbacks import Callback

class metrics(Callback):
    def __init__(self, validation_data):
#         self.x = training_data[0]
#         self.y = training_data[1]
        self.x_val = validation_data[0]
        self.y_val = validation_data[1]


    def on_train_begin(self, logs={}):
        return

    def on_train_end(self, logs={}):
        return

    def on_epoch_begin(self, epoch, logs={}):
        return

    def on_epoch_end(self, epoch, logs={}):
#         y_pred = self.model.predict(self.x)
#         roc = roc_auc_score(self.y, y_pred)
#         prec = precision_score(np.ndarray.flatten((self.y).astype(int)), np.ndarray.flatten((y_pred > 0.5).astype(int)))
#         recall = recall_score(np.ndarray.flatten((self.y).astype(int)), np.ndarray.flatten((y_pred > 0.5).astype(int)))
        
        y_pred_val = self.model.predict(self.x_val)
        roc_val = roc_auc_score(self.y_val, y_pred_val > 0.5)
        prec_val = precision_score(np.ndarray.flatten((self.y_val).astype(int)), np.ndarray.flatten((y_pred_val > 0.5).astype(int)))
        recall_val = recall_score(np.ndarray.flatten((self.y_val).astype(int)), np.ndarray.flatten((y_pred_val > 0.5).astype(int)))
        
        print('\rroc-auc_val: %s' % (str(round(roc_val,4))),end=100*' '+'\n')
        print('\rprecision_val: %s' % (str(round(prec_val,4))),end=100*' '+'\n')
        print('\rrecall_val: %s' % (str(round(recall_val,4))),end=100*' '+'\n')
        
#         print('\rroc-auc: %s - roc-auc_val: %s' % (str(round(roc,4)),str(round(roc_val,4))),end=100*' '+'\n')
#         print('\rprecision: %s - precision_val: %s' % (str(round(prec,4)),str(round(prec_val,4))),end=100*' '+'\n')
#         print('\rrecall: %s - recall_val: %s' % (str(round(recall,4)),str(round(recall_val,4))),end=100*' '+'\n')
        return

    def on_batch_begin(self, batch, logs={}):
        return

    def on_batch_end(self, batch, logs={}):
        return

# %%
# train_inp.shape, train_out.shape


# model.fit( \
#           X_train, \
#           y_train, \
#           validation_data=(X_val, y_val),
#           batch_size=64, \
#           epochs=1000, \
#           callbacks=[metrics(training_data=(X_train, y_train), validation_data=(X_val, y_val))],
#          )

MASK_PROB = 0.15 #@param {type:"number"}
MASK_ERROR_PROB = 0.8 #@param {type:"number"}
BATCH_SIZE = 64 #@param {type:"number"}

tr, val = train_test_split(train[:TRAIN_SIZE], test_size=0.2, shuffle=False)
train_gen = dataset_generator(tr.main_content, MASK_PROB, MASK_ERROR_PROB, batch_size=BATCH_SIZE)
X_val, y_val = next(dataset_generator(val.main_content, MASK_PROB, MASK_ERROR_PROB, batch_size=BATCH_SIZE * 100))

model.fit_generator( \
          train_gen, \
          steps_per_epoch = 1000, \
          validation_data=(X_val, y_val), \
          callbacks=[metrics(validation_ data=(X_val, y_val))], \
          epochs=10000,
         )
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_impl.py:112: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/10000
# roc-auc_val: 0.5713
# precision_val: 0.8078
# recall_val: 0.1473
# 1000/1000 [==============================] - 146s 146ms/step - loss: 0.3616 - mean_absolute_error: 0.2087 - acc: 0.8820 - val_loss: 0.3201 - val_mean_absolute_error: 0.1850 - val_acc: 0.8939
# Epoch 2/10000
# roc-auc_val: 0.6316
# precision_val: 0.7702
# recall_val: 0.2741
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.2942 - mean_absolute_error: 0.1687 - acc: 0.8976 - val_loss: 0.2667 - val_mean_absolute_error: 0.1507 - val_acc: 0.9035
# Epoch 3/10000
# roc-auc_val: 0.6793
# precision_val: 0.7244
# recall_val: 0.378
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.2546 - mean_absolute_error: 0.1474 - acc: 0.9061 - val_loss: 0.2454 - val_mean_absolute_error: 0.1458 - val_acc: 0.9085
# Epoch 4/10000
# roc-auc_val: 0.6884
# precision_val: 0.7569
# recall_val: 0.3938
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.2380 - mean_absolute_error: 0.1383 - acc: 0.9104 - val_loss: 0.2318 - val_mean_absolute_error: 0.1370 - val_acc: 0.9125
# Epoch 5/10000
# roc-auc_val: 0.6995
# precision_val: 0.7645
# recall_val: 0.4164
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.2267 - mean_absolute_error: 0.1321 - acc: 0.9137 - val_loss: 0.2225 - val_mean_absolute_error: 0.1308 - val_acc: 0.9150
# Epoch 6/10000
# roc-auc_val: 0.7121
# precision_val: 0.7629
# recall_val: 0.4429
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.2200 - mean_absolute_error: 0.1285 - acc: 0.9154 - val_loss: 0.2156 - val_mean_absolute_error: 0.1253 - val_acc: 0.9170
# Epoch 7/10000
# roc-auc_val: 0.7143
# precision_val: 0.7757
# recall_val: 0.4459
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.2133 - mean_absolute_error: 0.1246 - acc: 0.9178 - val_loss: 0.2111 - val_mean_absolute_error: 0.1209 - val_acc: 0.9184
# Epoch 8/10000
# roc-auc_val: 0.7261
# precision_val: 0.7676
# recall_val: 0.4714
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.2080 - mean_absolute_error: 0.1217 - acc: 0.9193 - val_loss: 0.2065 - val_mean_absolute_error: 0.1227 - val_acc: 0.9198
# Epoch 9/10000
# roc-auc_val: 0.7312
# precision_val: 0.7712
# recall_val: 0.4817
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.2047 - mean_absolute_error: 0.1200 - acc: 0.9202 - val_loss: 0.2025 - val_mean_absolute_error: 0.1186 - val_acc: 0.9210
# Epoch 10/10000
# roc-auc_val: 0.735
# precision_val: 0.7704
# recall_val: 0.4898
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.2008 - mean_absolute_error: 0.1177 - acc: 0.9215 - val_loss: 0.1997 - val_mean_absolute_error: 0.1195 - val_acc: 0.9216
# Epoch 11/10000
# roc-auc_val: 0.7339
# precision_val: 0.7856
# recall_val: 0.4856
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1979 - mean_absolute_error: 0.1161 - acc: 0.9225 - val_loss: 0.1968 - val_mean_absolute_error: 0.1132 - val_acc: 0.9227
# Epoch 12/10000
# roc-auc_val: 0.7469
# precision_val: 0.7677
# recall_val: 0.5148
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1964 - mean_absolute_error: 0.1154 - acc: 0.9227 - val_loss: 0.1947 - val_mean_absolute_error: 0.1148 - val_acc: 0.9234
# Epoch 13/10000
# roc-auc_val: 0.7463
# precision_val: 0.7795
# recall_val: 0.512
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1924 - mean_absolute_error: 0.1132 - acc: 0.9241 - val_loss: 0.1921 - val_mean_absolute_error: 0.1129 - val_acc: 0.9244
# Epoch 14/10000
# roc-auc_val: 0.7466
# precision_val: 0.7839
# recall_val: 0.5122
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1909 - mean_absolute_error: 0.1122 - acc: 0.9246 - val_loss: 0.1902 - val_mean_absolute_error: 0.1118 - val_acc: 0.9249
# Epoch 15/10000
# roc-auc_val: 0.7532
# precision_val: 0.7795
# recall_val: 0.5264
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1894 - mean_absolute_error: 0.1114 - acc: 0.9251 - val_loss: 0.1881 - val_mean_absolute_error: 0.1100 - val_acc: 0.9256
# Epoch 16/10000
# roc-auc_val: 0.7508
# precision_val: 0.7849
# recall_val: 0.5209
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1872 - mean_absolute_error: 0.1101 - acc: 0.9257 - val_loss: 0.1864 - val_mean_absolute_error: 0.1094 - val_acc: 0.9257
# Epoch 17/10000
# roc-auc_val: 0.7591
# precision_val: 0.7787
# recall_val: 0.5387
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1858 - mean_absolute_error: 0.1094 - acc: 0.9264 - val_loss: 0.1853 - val_mean_absolute_error: 0.1074 - val_acc: 0.9266
# Epoch 18/10000
# roc-auc_val: 0.7623
# precision_val: 0.7705
# recall_val: 0.5464
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1840 - mean_absolute_error: 0.1082 - acc: 0.9270 - val_loss: 0.1838 - val_mean_absolute_error: 0.1085 - val_acc: 0.9264
# Epoch 19/10000
# roc-auc_val: 0.7599
# precision_val: 0.7785
# recall_val: 0.5405
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1827 - mean_absolute_error: 0.1076 - acc: 0.9273 - val_loss: 0.1826 - val_mean_absolute_error: 0.1076 - val_acc: 0.9267
# Epoch 20/10000
# roc-auc_val: 0.7688
# precision_val: 0.7695
# recall_val: 0.56
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1809 - mean_absolute_error: 0.1065 - acc: 0.9281 - val_loss: 0.1818 - val_mean_absolute_error: 0.1080 - val_acc: 0.9274
# Epoch 21/10000
# roc-auc_val: 0.7584
# precision_val: 0.7928
# recall_val: 0.5357
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1801 - mean_absolute_error: 0.1061 - acc: 0.9283 - val_loss: 0.1809 - val_mean_absolute_error: 0.1047 - val_acc: 0.9278
# Epoch 22/10000
# roc-auc_val: 0.7666
# precision_val: 0.783
# recall_val: 0.5538
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1792 - mean_absolute_error: 0.1055 - acc: 0.9286 - val_loss: 0.1799 - val_mean_absolute_error: 0.1041 - val_acc: 0.9284
# Epoch 23/10000
# roc-auc_val: 0.7653
# precision_val: 0.7859
# recall_val: 0.5508
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1783 - mean_absolute_error: 0.1050 - acc: 0.9289 - val_loss: 0.1792 - val_mean_absolute_error: 0.1039 - val_acc: 0.9284
# Epoch 24/10000
# roc-auc_val: 0.7743
# precision_val: 0.7749
# recall_val: 0.5709
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1780 - mean_absolute_error: 0.1049 - acc: 0.9289 - val_loss: 0.1779 - val_mean_absolute_error: 0.1066 - val_acc: 0.9289
# Epoch 25/10000
# roc-auc_val: 0.7722
# precision_val: 0.7841
# recall_val: 0.5652
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1776 - mean_absolute_error: 0.1046 - acc: 0.9292 - val_loss: 0.1774 - val_mean_absolute_error: 0.1029 - val_acc: 0.9295
# Epoch 26/10000
# roc-auc_val: 0.7707
# precision_val: 0.7883
# recall_val: 0.5616
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1761 - mean_absolute_error: 0.1037 - acc: 0.9298 - val_loss: 0.1761 - val_mean_absolute_error: 0.1031 - val_acc: 0.9296
# Epoch 27/10000
# roc-auc_val: 0.7777
# precision_val: 0.7812
# recall_val: 0.5772
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1751 - mean_absolute_error: 0.1031 - acc: 0.9302 - val_loss: 0.1756 - val_mean_absolute_error: 0.1024 - val_acc: 0.9302
# Epoch 28/10000
# roc-auc_val: 0.7789
# precision_val: 0.7804
# recall_val: 0.5798
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1742 - mean_absolute_error: 0.1026 - acc: 0.9305 - val_loss: 0.1757 - val_mean_absolute_error: 0.1038 - val_acc: 0.9303
# Epoch 29/10000
# roc-auc_val: 0.7806
# precision_val: 0.7751
# recall_val: 0.5841
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1738 - mean_absolute_error: 0.1024 - acc: 0.9307 - val_loss: 0.1751 - val_mean_absolute_error: 0.1025 - val_acc: 0.9301
# Epoch 30/10000
# roc-auc_val: 0.7748
# precision_val: 0.7896
# recall_val: 0.5701
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1730 - mean_absolute_error: 0.1019 - acc: 0.9310 - val_loss: 0.1740 - val_mean_absolute_error: 0.1010 - val_acc: 0.9305
# Epoch 31/10000
# roc-auc_val: 0.7797
# precision_val: 0.7842
# recall_val: 0.581
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1734 - mean_absolute_error: 0.1022 - acc: 0.9307 - val_loss: 0.1733 - val_mean_absolute_error: 0.1022 - val_acc: 0.9308
# Epoch 32/10000
# roc-auc_val: 0.7757
# precision_val: 0.7933
# recall_val: 0.5715
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1718 - mean_absolute_error: 0.1011 - acc: 0.9315 - val_loss: 0.1735 - val_mean_absolute_error: 0.1009 - val_acc: 0.9310
# Epoch 33/10000
# roc-auc_val: 0.779
# precision_val: 0.793
# recall_val: 0.5782
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1712 - mean_absolute_error: 0.1008 - acc: 0.9318 - val_loss: 0.1725 - val_mean_absolute_error: 0.0995 - val_acc: 0.9316
# Epoch 34/10000
# roc-auc_val: 0.7749
# precision_val: 0.801
# recall_val: 0.5688
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1710 - mean_absolute_error: 0.1007 - acc: 0.9318 - val_loss: 0.1721 - val_mean_absolute_error: 0.0990 - val_acc: 0.9316
# Epoch 35/10000
# roc-auc_val: 0.7853
# precision_val: 0.7792
# recall_val: 0.5933
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1705 - mean_absolute_error: 0.1003 - acc: 0.9321 - val_loss: 0.1714 - val_mean_absolute_error: 0.1020 - val_acc: 0.9313
# Epoch 36/10000
# roc-auc_val: 0.7868
# precision_val: 0.7827
# recall_val: 0.5958
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1695 - mean_absolute_error: 0.0998 - acc: 0.9324 - val_loss: 0.1708 - val_mean_absolute_error: 0.1008 - val_acc: 0.9320
# Epoch 37/10000
# roc-auc_val: 0.7875
# precision_val: 0.7826
# recall_val: 0.5973
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1690 - mean_absolute_error: 0.0995 - acc: 0.9325 - val_loss: 0.1706 - val_mean_absolute_error: 0.1003 - val_acc: 0.9321
# Epoch 38/10000
# roc-auc_val: 0.7898
# precision_val: 0.7757
# recall_val: 0.6031
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1687 - mean_absolute_error: 0.0992 - acc: 0.9326 - val_loss: 0.1704 - val_mean_absolute_error: 0.1005 - val_acc: 0.9317
# Epoch 39/10000
# roc-auc_val: 0.7809
# precision_val: 0.7939
# recall_val: 0.5822
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1688 - mean_absolute_error: 0.0994 - acc: 0.9326 - val_loss: 0.1700 - val_mean_absolute_error: 0.0993 - val_acc: 0.9320
# Epoch 40/10000
# roc-auc_val: 0.7851
# precision_val: 0.7891
# recall_val: 0.5915
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1689 - mean_absolute_error: 0.0995 - acc: 0.9326 - val_loss: 0.1687 - val_mean_absolute_error: 0.1002 - val_acc: 0.9323
# Epoch 41/10000
# roc-auc_val: 0.7862
# precision_val: 0.7909
# recall_val: 0.5935
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1679 - mean_absolute_error: 0.0989 - acc: 0.9329 - val_loss: 0.1694 - val_mean_absolute_error: 0.0995 - val_acc: 0.9327
# Epoch 42/10000
# roc-auc_val: 0.7835
# precision_val: 0.7983
# recall_val: 0.5869
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1675 - mean_absolute_error: 0.0985 - acc: 0.9331 - val_loss: 0.1686 - val_mean_absolute_error: 0.0981 - val_acc: 0.9329
# Epoch 43/10000
# roc-auc_val: 0.7902
# precision_val: 0.7859
# recall_val: 0.6024
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1673 - mean_absolute_error: 0.0984 - acc: 0.9331 - val_loss: 0.1680 - val_mean_absolute_error: 0.0983 - val_acc: 0.9329
# Epoch 44/10000
# roc-auc_val: 0.7884
# precision_val: 0.7905
# recall_val: 0.5982
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1670 - mean_absolute_error: 0.0983 - acc: 0.9333 - val_loss: 0.1671 - val_mean_absolute_error: 0.0979 - val_acc: 0.9331
# Epoch 45/10000
# roc-auc_val: 0.7883
# precision_val: 0.7951
# recall_val: 0.5972
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1661 - mean_absolute_error: 0.0977 - acc: 0.9337 - val_loss: 0.1673 - val_mean_absolute_error: 0.0979 - val_acc: 0.9335
# Epoch 46/10000
# roc-auc_val: 0.7973
# precision_val: 0.7725
# recall_val: 0.6192
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1658 - mean_absolute_error: 0.0976 - acc: 0.9338 - val_loss: 0.1672 - val_mean_absolute_error: 0.0982 - val_acc: 0.9327
# Epoch 47/10000
# roc-auc_val: 0.7803
# precision_val: 0.8058
# recall_val: 0.5794
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1655 - mean_absolute_error: 0.0974 - acc: 0.9340 - val_loss: 0.1678 - val_mean_absolute_error: 0.0951 - val_acc: 0.9331
# Epoch 48/10000
# roc-auc_val: 0.7909
# precision_val: 0.7967
# recall_val: 0.6024
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1655 - mean_absolute_error: 0.0974 - acc: 0.9338 - val_loss: 0.1667 - val_mean_absolute_error: 0.0983 - val_acc: 0.9341
# Epoch 49/10000
# roc-auc_val: 0.7891
# precision_val: 0.8008
# recall_val: 0.5982
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1643 - mean_absolute_error: 0.0966 - acc: 0.9344 - val_loss: 0.1662 - val_mean_absolute_error: 0.0958 - val_acc: 0.9342
# Epoch 50/10000
# roc-auc_val: 0.7942
# precision_val: 0.7893
# recall_val: 0.6104
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1649 - mean_absolute_error: 0.0971 - acc: 0.9340 - val_loss: 0.1665 - val_mean_absolute_error: 0.0981 - val_acc: 0.9340
# Epoch 51/10000
# roc-auc_val: 0.7982
# precision_val: 0.7804
# recall_val: 0.6199
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1642 - mean_absolute_error: 0.0966 - acc: 0.9344 - val_loss: 0.1660 - val_mean_absolute_error: 0.0968 - val_acc: 0.9338
# Epoch 52/10000
# roc-auc_val: 0.7928
# precision_val: 0.7902
# recall_val: 0.6074
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1628 - mean_absolute_error: 0.0958 - acc: 0.9349 - val_loss: 0.1653 - val_mean_absolute_error: 0.0967 - val_acc: 0.9338
# Epoch 53/10000
# roc-auc_val: 0.7868
# precision_val: 0.8076
# recall_val: 0.5927
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1636 - mean_absolute_error: 0.0964 - acc: 0.9344 - val_loss: 0.1651 - val_mean_absolute_error: 0.0948 - val_acc: 0.9345
# Epoch 54/10000
# roc-auc_val: 0.7876
# precision_val: 0.7988
# recall_val: 0.5953
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1641 - mean_absolute_error: 0.0967 - acc: 0.9341 - val_loss: 0.1660 - val_mean_absolute_error: 0.0974 - val_acc: 0.9337
# Epoch 55/10000
# roc-auc_val: 0.7921
# precision_val: 0.7951
# recall_val: 0.6053
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1641 - mean_absolute_error: 0.0965 - acc: 0.9342 - val_loss: 0.1650 - val_mean_absolute_error: 0.0963 - val_acc: 0.9342
# Epoch 56/10000
# roc-auc_val: 0.7931
# precision_val: 0.7941
# recall_val: 0.6074
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1640 - mean_absolute_error: 0.0965 - acc: 0.9344 - val_loss: 0.1645 - val_mean_absolute_error: 0.0971 - val_acc: 0.9343
# Epoch 57/10000
# roc-auc_val: 0.7912
# precision_val: 0.7975
# recall_val: 0.6031
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1634 - mean_absolute_error: 0.0961 - acc: 0.9348 - val_loss: 0.1640 - val_mean_absolute_error: 0.0947 - val_acc: 0.9343
# Epoch 58/10000
# roc-auc_val: 0.7944
# precision_val: 0.795
# recall_val: 0.61
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1625 - mean_absolute_error: 0.0955 - acc: 0.9351 - val_loss: 0.1639 - val_mean_absolute_error: 0.0963 - val_acc: 0.9346
# Epoch 59/10000
# roc-auc_val: 0.7986
# precision_val: 0.7904
# recall_val: 0.6193
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1625 - mean_absolute_error: 0.0955 - acc: 0.9351 - val_loss: 0.1636 - val_mean_absolute_error: 0.0958 - val_acc: 0.9349
# Epoch 60/10000
# roc-auc_val: 0.7932
# precision_val: 0.8029
# recall_val: 0.6064
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1628 - mean_absolute_error: 0.0957 - acc: 0.9349 - val_loss: 0.1631 - val_mean_absolute_error: 0.0953 - val_acc: 0.9352
# Epoch 61/10000
# roc-auc_val: 0.7957
# precision_val: 0.7956
# recall_val: 0.6125
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1616 - mean_absolute_error: 0.0950 - acc: 0.9353 - val_loss: 0.1632 - val_mean_absolute_error: 0.0961 - val_acc: 0.9349
# Epoch 62/10000
# roc-auc_val: 0.8002
# precision_val: 0.7886
# recall_val: 0.6229
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1613 - mean_absolute_error: 0.0948 - acc: 0.9356 - val_loss: 0.1626 - val_mean_absolute_error: 0.0951 - val_acc: 0.9350
# Epoch 63/10000
# roc-auc_val: 0.7969
# precision_val: 0.7962
# recall_val: 0.6151
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1618 - mean_absolute_error: 0.0951 - acc: 0.9353 - val_loss: 0.1629 - val_mean_absolute_error: 0.0962 - val_acc: 0.9352
# Epoch 64/10000
# roc-auc_val: 0.799
# precision_val: 0.7893
# recall_val: 0.6203
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1616 - mean_absolute_error: 0.0951 - acc: 0.9352 - val_loss: 0.1620 - val_mean_absolute_error: 0.0948 - val_acc: 0.9349
# Epoch 65/10000
# roc-auc_val: 0.7906
# precision_val: 0.8052
# recall_val: 0.6008
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1611 - mean_absolute_error: 0.0947 - acc: 0.9358 - val_loss: 0.1626 - val_mean_absolute_error: 0.0938 - val_acc: 0.9349
# Epoch 66/10000
# roc-auc_val: 0.797
# precision_val: 0.7956
# recall_val: 0.6153
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1616 - mean_absolute_error: 0.0950 - acc: 0.9354 - val_loss: 0.1621 - val_mean_absolute_error: 0.0950 - val_acc: 0.9352
# Epoch 67/10000
# roc-auc_val: 0.8025
# precision_val: 0.7908
# recall_val: 0.6273
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1611 - mean_absolute_error: 0.0948 - acc: 0.9355 - val_loss: 0.1613 - val_mean_absolute_error: 0.0945 - val_acc: 0.9356
# Epoch 68/10000
# roc-auc_val: 0.8047
# precision_val: 0.7904
# recall_val: 0.6318
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.1613 - mean_absolute_error: 0.0948 - acc: 0.9355 - val_loss: 0.1616 - val_mean_absolute_error: 0.0961 - val_acc: 0.9360
# Epoch 69/10000
# roc-auc_val: 0.8038
# precision_val: 0.786
# recall_val: 0.6306
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1606 - mean_absolute_error: 0.0945 - acc: 0.9358 - val_loss: 0.1618 - val_mean_absolute_error: 0.0947 - val_acc: 0.9354
# Epoch 70/10000
# roc-auc_val: 0.7985
# precision_val: 0.7954
# recall_val: 0.6184
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1600 - mean_absolute_error: 0.0941 - acc: 0.9360 - val_loss: 0.1616 - val_mean_absolute_error: 0.0937 - val_acc: 0.9354
# Epoch 71/10000
# roc-auc_val: 0.8021
# precision_val: 0.789
# recall_val: 0.6267
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1613 - mean_absolute_error: 0.0948 - acc: 0.9355 - val_loss: 0.1619 - val_mean_absolute_error: 0.0957 - val_acc: 0.9354
# Epoch 72/10000
# roc-auc_val: 0.7996
# precision_val: 0.7974
# recall_val: 0.6204
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1605 - mean_absolute_error: 0.0944 - acc: 0.9358 - val_loss: 0.1613 - val_mean_absolute_error: 0.0938 - val_acc: 0.9358
# Epoch 73/10000
# roc-auc_val: 0.8049
# precision_val: 0.7871
# recall_val: 0.6327
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1601 - mean_absolute_error: 0.0941 - acc: 0.9361 - val_loss: 0.1612 - val_mean_absolute_error: 0.0944 - val_acc: 0.9357
# Epoch 74/10000
# roc-auc_val: 0.8116
# precision_val: 0.7767
# recall_val: 0.6481
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1603 - mean_absolute_error: 0.0942 - acc: 0.9359 - val_loss: 0.1620 - val_mean_absolute_error: 0.0963 - val_acc: 0.9357
# Epoch 75/10000
# roc-auc_val: 0.7997
# precision_val: 0.7919
# recall_val: 0.6214
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1598 - mean_absolute_error: 0.0939 - acc: 0.9362 - val_loss: 0.1614 - val_mean_absolute_error: 0.0951 - val_acc: 0.9353
# Epoch 76/10000
# roc-auc_val: 0.8023
# precision_val: 0.7937
# recall_val: 0.6265
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1603 - mean_absolute_error: 0.0943 - acc: 0.9360 - val_loss: 0.1612 - val_mean_absolute_error: 0.0941 - val_acc: 0.9359
# Epoch 77/10000
# roc-auc_val: 0.7999
# precision_val: 0.8013
# recall_val: 0.6205
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1596 - mean_absolute_error: 0.0938 - acc: 0.9361 - val_loss: 0.1601 - val_mean_absolute_error: 0.0933 - val_acc: 0.9363
# Epoch 78/10000
# roc-auc_val: 0.8074
# precision_val: 0.7856
# recall_val: 0.6381
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1593 - mean_absolute_error: 0.0937 - acc: 0.9363 - val_loss: 0.1601 - val_mean_absolute_error: 0.0946 - val_acc: 0.9360
# Epoch 79/10000
# roc-auc_val: 0.8042
# precision_val: 0.7917
# recall_val: 0.6307
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1595 - mean_absolute_error: 0.0937 - acc: 0.9361 - val_loss: 0.1602 - val_mean_absolute_error: 0.0937 - val_acc: 0.9361
# Epoch 80/10000
# roc-auc_val: 0.7976
# precision_val: 0.7991
# recall_val: 0.6161
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1587 - mean_absolute_error: 0.0933 - acc: 0.9366 - val_loss: 0.1608 - val_mean_absolute_error: 0.0932 - val_acc: 0.9356
# Epoch 81/10000
# roc-auc_val: 0.8031
# precision_val: 0.7903
# recall_val: 0.6287
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1592 - mean_absolute_error: 0.0936 - acc: 0.9362 - val_loss: 0.1602 - val_mean_absolute_error: 0.0941 - val_acc: 0.9357
# Epoch 82/10000
# roc-auc_val: 0.8076
# precision_val: 0.7806
# recall_val: 0.6393
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1591 - mean_absolute_error: 0.0934 - acc: 0.9365 - val_loss: 0.1606 - val_mean_absolute_error: 0.0943 - val_acc: 0.9354
# Epoch 83/10000
# roc-auc_val: 0.7979
# precision_val: 0.8011
# recall_val: 0.6164
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1586 - mean_absolute_error: 0.0932 - acc: 0.9366 - val_loss: 0.1602 - val_mean_absolute_error: 0.0926 - val_acc: 0.9359
# Epoch 84/10000
# roc-auc_val: 0.8085
# precision_val: 0.7851
# recall_val: 0.6406
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1590 - mean_absolute_error: 0.0934 - acc: 0.9364 - val_loss: 0.1598 - val_mean_absolute_error: 0.0944 - val_acc: 0.9361
# Epoch 85/10000
# roc-auc_val: 0.7991
# precision_val: 0.7969
# recall_val: 0.6193
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1587 - mean_absolute_error: 0.0932 - acc: 0.9368 - val_loss: 0.1604 - val_mean_absolute_error: 0.0932 - val_acc: 0.9357
# Epoch 86/10000
# roc-auc_val: 0.8024
# precision_val: 0.7923
# recall_val: 0.6269
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1585 - mean_absolute_error: 0.0931 - acc: 0.9366 - val_loss: 0.1606 - val_mean_absolute_error: 0.0941 - val_acc: 0.9358
# Epoch 87/10000
# roc-auc_val: 0.8069
# precision_val: 0.7833
# recall_val: 0.6374
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1576 - mean_absolute_error: 0.0926 - acc: 0.9370 - val_loss: 0.1602 - val_mean_absolute_error: 0.0935 - val_acc: 0.9356
# Epoch 88/10000
# roc-auc_val: 0.8011
# precision_val: 0.7961
# recall_val: 0.6237
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1580 - mean_absolute_error: 0.0927 - acc: 0.9370 - val_loss: 0.1607 - val_mean_absolute_error: 0.0938 - val_acc: 0.9360
# Epoch 89/10000
# roc-auc_val: 0.8048
# precision_val: 0.7886
# recall_val: 0.6323
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1581 - mean_absolute_error: 0.0928 - acc: 0.9369 - val_loss: 0.1606 - val_mean_absolute_error: 0.0934 - val_acc: 0.9358
# Epoch 90/10000
# roc-auc_val: 0.7961
# precision_val: 0.8063
# recall_val: 0.6119
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1580 - mean_absolute_error: 0.0929 - acc: 0.9369 - val_loss: 0.1605 - val_mean_absolute_error: 0.0917 - val_acc: 0.9361
# Epoch 91/10000
# roc-auc_val: 0.8035
# precision_val: 0.7933
# recall_val: 0.6292
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1576 - mean_absolute_error: 0.0925 - acc: 0.9370 - val_loss: 0.1601 - val_mean_absolute_error: 0.0935 - val_acc: 0.9361
# Epoch 92/10000
#  999/1000 [============================>.] - ETA: 0s - loss: 0.1579 - mean_absolute_error: 0.0928 - acc: 0.9368
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-d5bcd2917a2a> in <module>()
#       8 X_val, y_val = next(dataset_generator(val.main_content, MASK_PROB, MASK_ERROR_PROB, batch_size=BATCH_SIZE * 100))
#       9
# ---> 10 model.fit_generator(           train_gen,           steps_per_epoch = 1000,           validation_data=(X_val, y_val),           callbacks=[metrics(validation_data=(X_val, y_val))],           epochs=10000,
#      11          )
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2175         use_multiprocessing=use_multiprocessing,
#    2176         shuffle=shuffle,
# -> 2177         initial_epoch=initial_epoch)
#    2178
#    2179   def evaluate_generator(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     214           break
#     215
# --> 216       callbacks.on_epoch_end(epoch, epoch_logs)
#     217       epoch += 1
#     218       if callbacks.model.stop_training:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#     212     logs = logs or {}
#     213     for callback in self.callbacks:
# --> 214       callback.on_epoch_end(epoch, logs)
#     215
#     216   def on_batch_begin(self, batch, logs=None):
#
# <ipython-input-41-6829d3ffd035> in on_epoch_end(self, epoch, logs)
#      25 #         recall = recall_score(np.ndarray.flatten((self.y).astype(int)), np.ndarray.flatten((y_pred > 0.5).astype(int)))
#      26
# ---> 27         y_pred_val = self.model.predict(self.x_val)
#      28         roc_val = roc_auc_score(self.y_val, y_pred_val > 0.5)
#      29         prec_val = precision_score(np.ndarray.flatten((self.y_val).astype(int)), np.ndarray.flatten((y_pred_val > 0.5).astype(int)))
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, max_queue_size, workers, use_multiprocessing)
#    1876     else:
#    1877       return training_arrays.predict_loop(
# -> 1878           self, x, batch_size=batch_size, verbose=verbose, steps=steps)
#    1879
#    1880   def train_on_batch(self, x, y=None, sample_weight=None, class_weight=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training_arrays.py in predict_loop(model, inputs, batch_size, verbose, steps)
#     324         ins_batch[i] = ins_batch[i].toarray()
#     325
# --> 326       batch_outs = f(ins_batch)
#     327       if not isinstance(batch_outs, list):
#     328         batch_outs = [batch_outs]
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    2984
#    2985     fetched = self._callable_fn(*array_vals,
# -> 2986                                 run_metadata=self.run_metadata)
#    2987     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    2988     return fetched[:len(self.outputs)]
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
test_gen = dataset_generator(test[:1].main_content, MASK_PROB, MASK_ERROR_PROB, batch_size=BATCH_SIZE)

# %%
test_inp, test_out = next(test_gen)
test_pred = model.predict(test_inp)

# %%
visualize(test_inp, test_out, test_pred)

# %%
raw_test_gen = dataset_generator(test[:100].main_content, mask_prob=0., mask_error_prob=0., batch_size=BATCH_SIZE)

# %%
raw_test_inp, raw_test_out = next(raw_test_gen)
raw_test_pred = model.predict(raw_test_inp)

visualize(raw_test_inp, raw_test_out, raw_test_pred, display_rows=5)

# %%
# Improvement
# Better corpus
# Masked Loss Function (?)
# Pretrainined Word Vector (done)
# Better Typo Models
# Tune precision threshold
# Concat Char Level pretrainined word vectors
# Dropout and Regularization
# Random error probability per sentence
